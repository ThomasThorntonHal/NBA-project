# %% [markdown]
# # Introduction
# In this notebook we will look at how the popularity of certain shots have changed over time.
#
# ## Notebook Objectives
# The objective is to come up with a way to effectively visualise which shot locations are most popular.
#
# ## Learning Objectives
# To do this we will develop a shot chart.

# %% [markdown]
# # Notes
# Later in this notebook I will be using a variety of functions from GitHub user [eyalshafran](https://github.com/eyalshafran/NBAapi/blob/master/NBAapi/plot.py). The functions `shot_zone` and `court` are both fully written by eyalshafran. The shot chart plot is also mostly written by eyalshafran with some small adjustments to better fit my data.

# %% [markdown]
# # Setup
#
# ## Imports

# %%
from datetime import datetime

import pandas as pd

import numpy as np

import matplotlib.pylab as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

import matplotlib

import seaborn as sns

import numpy as np
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import LinearSegmentedColormap
from scipy import misc
import nba_api as nba

from scipy.ndimage.filters import gaussian_filter
from matplotlib import cm

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Rectangle, Arc
from matplotlib.offsetbox import OffsetImage,AnnotationBbox
from matplotlib import cm
from nba_api.stats.endpoints import shotchartdetail,leaguedashplayerbiostats
import seaborn as sns
from scipy.ndimage.filters import gaussian_filter
from skimage import io

# %matplotlib inline

# %%
from datetime import datetime

import pandas as pd

import numpy as np

import matplotlib.pylab as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from matplotlib.patches import Circle, Rectangle, Arc

import matplotlib

import seaborn as sns

import numpy as np
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import LinearSegmentedColormap
from scipy import misc
import nba_api as nba

# %matplotlib inline

# %% [markdown]
# ## Parameters

# %%
SHOT_DATASET = 'C:/Users/User/OneDrive/Desktop/DSIP/NBAproject/data/processed/210_position_shot_dataset.csv'

# %% [markdown]
# ## Configuration

# %%
sns.set_context('talk')

# %matplotlib inline

# %% [markdown]
# ## Load shots dataset

# %%
df = pd.read_csv(SHOT_DATASET)
df.shape, df.nunique()
# Out:
# ((2293539, 18),
#  GAME_ID                13875
#  GAME_EVENT_ID            900
#  PLAYER_ID               1338
#  PLAYER_NAME             1334
#  TEAM_ID                   30
#  TEAM_NAME                 30
#  SHOT_TYPE                  2
#  SHOT_ZONE_BASIC            7
#  SHOT_ZONE_AREA             6
#  SHOT_ZONE_RANGE            5
#  SHOT_DISTANCE             90
#  LOC_X                    501
#  LOC_Y                    892
#  SHOT_ATTEMPTED_FLAG        1
#  SHOT_MADE_FLAG             2
#  GAME_DATE               1846
#  SEASON                    12
#  POSITION                   3
#  dtype: int64)

# %%
df.head()
# Out:
#     GAME_ID  GAME_EVENT_ID  PLAYER_ID PLAYER_NAME     TEAM_ID      TEAM_NAME  \
# 0  20900005            140        693   Joe Smith  1610612737  Atlanta Hawks
# 1  20900005            148        693   Joe Smith  1610612737  Atlanta Hawks
# 2  20900005            155        693   Joe Smith  1610612737  Atlanta Hawks
# 3  20900005            168        693   Joe Smith  1610612737  Atlanta Hawks
# 4  20900005            426        693   Joe Smith  1610612737  Atlanta Hawks
#
#         SHOT_TYPE        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 0  2PT Field Goal              Mid-Range  Right Side Center(RC)
# 1  2PT Field Goal              Mid-Range          Right Side(R)
# 2  2PT Field Goal              Mid-Range              Center(C)
# 3  2PT Field Goal        Restricted Area              Center(C)
# 4  2PT Field Goal  In The Paint (Non-RA)              Center(C)
#
#    SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  \
# 0        16-24 ft.             18    106    151                    1
# 1        16-24 ft.             17    171     47                    1
# 2        16-24 ft.             17    -35    172                    1
# 3  Less Than 8 ft.              2     21     -2                    1
# 4  Less Than 8 ft.              7     -7     71                    1
#
#    SHOT_MADE_FLAG  GAME_DATE  SEASON POSITION
# 0               0   20091028    2009        F
# 1               1   20091028    2009        F
# 2               0   20091028    2009        F
# 3               1   20091028    2009        F
# 4               0   20091028    2009        F

# %%
df['SHOT_ZONE_BASIC'].value_counts()
# Out:
# Restricted Area          739461
# Mid-Range                547002
# Above the Break 3        493826
# In The Paint (Non-RA)    345211
# Left Corner 3             84488
# Right Corner 3            78575
# Backcourt                  4976
# Name: SHOT_ZONE_BASIC, dtype: int64

# %%
df['SHOT_ZONE_AREA'].value_counts()
# Out:
# Center(C)                1263206
# Right Side Center(RC)     272376
# Left Side Center(LC)      269108
# Left Side(L)              248100
# Right Side(R)             235076
# Back Court(BC)              5673
# Name: SHOT_ZONE_AREA, dtype: int64

# %%
df['SHOT_ZONE_RANGE'].value_counts()
# Out:
# Less Than 8 ft.    951867
# 24+ ft.            656192
# 16-24 ft.          361234
# 8-16 ft.           318573
# Back Court Shot      5673
# Name: SHOT_ZONE_RANGE, dtype: int64

# %%
df.loc[:,'SHOT_ZONE_AREA':'POSITION']
# Out:
#                 SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  \
# 0        Right Side Center(RC)        16-24 ft.             18    106    151
# 1                Right Side(R)        16-24 ft.             17    171     47
# 2                    Center(C)        16-24 ft.             17    -35    172
# 3                    Center(C)  Less Than 8 ft.              2     21     -2
# 4                    Center(C)  Less Than 8 ft.              7     -7     71
# ...                        ...              ...            ...    ...    ...
# 2293534           Left Side(L)          24+ ft.             23   -230     40
# 2293535              Center(C)  Less Than 8 ft.              0      7      3
# 2293536              Center(C)  Less Than 8 ft.              4     40      1
# 2293537              Center(C)  Less Than 8 ft.              4    -43     -4
# 2293538              Center(C)         8-16 ft.             13     -9    131
#
#          SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  SEASON POSITION
# 0                          1               0   20091028    2009        F
# 1                          1               1   20091028    2009        F
# 2                          1               0   20091028    2009        F
# 3                          1               1   20091028    2009        F
# 4                          1               0   20091028    2009        F
# ...                      ...             ...        ...     ...      ...
# 2293534                    1               0   20210407    2020      NaN
# 2293535                    1               1   20210407    2020      NaN
# 2293536                    1               1   20210407    2020      NaN
# 2293537                    1               1   20210407    2020      NaN
# 2293538                    1               0   20210407    2020      NaN
#
# [2293539 rows x 10 columns]

# %%
group_df = df[['SHOT_ZONE_AREA','SHOT_ZONE_RANGE','SHOT_DISTANCE','LOC_X','LOC_Y','SHOT_ATTEMPTED_FLAG','SHOT_MADE_FLAG','SEASON']]
group_df.head()
# Out:
#           SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  \
# 0  Right Side Center(RC)        16-24 ft.             18    106    151
# 1          Right Side(R)        16-24 ft.             17    171     47
# 2              Center(C)        16-24 ft.             17    -35    172
# 3              Center(C)  Less Than 8 ft.              2     21     -2
# 4              Center(C)  Less Than 8 ft.              7     -7     71
#
#    SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  SEASON
# 0                    1               0    2009
# 1                    1               1    2009
# 2                    1               0    2009
# 3                    1               1    2009
# 4                    1               0    2009

# %%
avg_shots_df = group_df.groupby(['SEASON', 'SHOT_ZONE_RANGE','SHOT_ZONE_AREA']).sum()
avg_shots_df
# Out:
#                                               SHOT_DISTANCE    LOC_X    LOC_Y  \
# SEASON SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   16-24 ft.       Center(C)                     145107    13774  1466959
#                        Left Side Center(LC)          175478 -1059127  1423258
#                        Left Side(L)                  156524 -1514739   402489
#                        Right Side Center(RC)         191313  1143951  1559612
#                        Right Side(R)                 140226  1357420   361039
# ...                                                     ...      ...      ...
# 2020   8-16 ft.        Center(C)                      69865     2779   699825
#                        Left Side(L)                   35184  -300833   169527
#                        Right Side(R)                  35007   296297   173433
#        Back Court Shot Back Court(BC)                  7175      776    70398
#        Less Than 8 ft. Center(C)                      83126    17063   678293
#
#                                               SHOT_ATTEMPTED_FLAG  \
# SEASON SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   16-24 ft.       Center(C)                             7729
#                        Left Side Center(LC)                  9400
#                        Left Side(L)                          8682
#                        Right Side Center(RC)                10166
#                        Right Side(R)                         7762
# ...                                                           ...
# 2020   8-16 ft.        Center(C)                             6182
#                        Left Side(L)                          3089
#                        Right Side(R)                         3087
#        Back Court Shot Back Court(BC)                         136
#        Less Than 8 ft. Center(C)                            35670
#
#                                               SHOT_MADE_FLAG
# SEASON SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   16-24 ft.       Center(C)                        3104
#                        Left Side Center(LC)             3651
#                        Left Side(L)                     3595
#                        Right Side Center(RC)            4007
#                        Right Side(R)                    3234
# ...                                                      ...
# 2020   8-16 ft.        Center(C)                        2784
#                        Left Side(L)                     1308
#                        Right Side(R)                    1328
#        Back Court Shot Back Court(BC)                      3
#        Less Than 8 ft. Center(C)                       20967
#
# [180 rows x 5 columns]

# %%
def league_area_pct(df):
    df['FG%'] = df['SHOT_MADE_FLAG']/df['SHOT_ATTEMPTED_FLAG']

# %%
league_area_pct(avg_shots_df)
avg_shots_df
# Out:
#                                               SHOT_DISTANCE    LOC_X    LOC_Y  \
# SEASON SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   16-24 ft.       Center(C)                     145107    13774  1466959
#                        Left Side Center(LC)          175478 -1059127  1423258
#                        Left Side(L)                  156524 -1514739   402489
#                        Right Side Center(RC)         191313  1143951  1559612
#                        Right Side(R)                 140226  1357420   361039
# ...                                                     ...      ...      ...
# 2020   8-16 ft.        Center(C)                      69865     2779   699825
#                        Left Side(L)                   35184  -300833   169527
#                        Right Side(R)                  35007   296297   173433
#        Back Court Shot Back Court(BC)                  7175      776    70398
#        Less Than 8 ft. Center(C)                      83126    17063   678293
#
#                                               SHOT_ATTEMPTED_FLAG  \
# SEASON SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   16-24 ft.       Center(C)                             7729
#                        Left Side Center(LC)                  9400
#                        Left Side(L)                          8682
#                        Right Side Center(RC)                10166
#                        Right Side(R)                         7762
# ...                                                           ...
# 2020   8-16 ft.        Center(C)                             6182
#                        Left Side(L)                          3089
#                        Right Side(R)                         3087
#        Back Court Shot Back Court(BC)                         136
#        Less Than 8 ft. Center(C)                            35670
#
#                                               SHOT_MADE_FLAG       FG%
# SEASON SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   16-24 ft.       Center(C)                        3104  0.401604
#                        Left Side Center(LC)             3651  0.388404
#                        Left Side(L)                     3595  0.414075
#                        Right Side Center(RC)            4007  0.394157
#                        Right Side(R)                    3234  0.416645
# ...                                                      ...       ...
# 2020   8-16 ft.        Center(C)                        2784  0.450340
#                        Left Side(L)                     1308  0.423438
#                        Right Side(R)                    1328  0.430191
#        Back Court Shot Back Court(BC)                      3  0.022059
#        Less Than 8 ft. Center(C)                       20967  0.587805
#
# [180 rows x 6 columns]

# %%
def player_area_pct(df):
    result = df.groupby(['SEASON','SHOT_ZONE_RANGE','SHOT_ZONE_AREA','SHOT_MADE_FLAG']).size().unstack(fill_value=0).copy()
    result['FG%'] = result.loc[:,1]/result.sum(axis=1)
    return result

# %%
luka_df = df[df['PLAYER_NAME']=='Luka Doncic']
luka_df = player_area_pct(luka_df)

# %%
luka_df.head()
# Out:
# SHOT_MADE_FLAG                                0  1       FG%
# SEASON SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2018   16-24 ft.       Center(C)              5  6  0.545455
#                        Left Side Center(LC)   9  8  0.470588
#                        Left Side(L)           5  0  0.000000
#                        Right Side Center(RC)  9  6  0.400000
#                        Right Side(R)          2  1  0.333333

# %%
def shot_zone(X,Y):
    '''
    Uses shot coordinates x and y (in feet - divide by 10 if using the shotchart units)
    and returns a tuple with the zone location
    '''
    r = np.sqrt(X**2+Y**2)
    a = np.arctan2(Y,X)*180.0/np.pi
    if (Y<0) & (X > 0):
        a = 0
    elif (Y<0) & (X < 0):
        a = 180
    if r<=8:
        z = ('Less Than 8 ft.','Center(C)')
    elif (r>8) & (r<=16):
        if a < 60:
            z = ('8-16 ft.','Right Side(R)')
        elif (a>=60) & (a<=120):
            z = ('8-16 ft.','Center(C)')
        else:
            z = ('8-16 ft.','Left Side(L)')
    elif (r>16) & (r<=23.75):
        if a < 36:
            z = ('16-24 ft.','Right Side(R)')
        elif (a>=36) & (a<72):
            z = ('16-24 ft.','Right Side Center(RC)')
        elif (a>=72) & (a<=108):
            z = ('16-24 ft.','Center(C)')
        elif (a>108) & (a<144):
            z = ('16-24 ft.','Left Side Center(LC)')
        else:
            z = ('16-24 ft.','Left Side(L)')
    elif r>23.75:
        if a < 72:
            z = ('24+ ft.','Right Side Center(RC)')
        elif (a>=72) & (a<=108):
            z = ('24+ ft.','Center(C)')
        else:
            z = ('24+ ft.','Left Side Center(LC)')
    if (np.abs(X)>=22):
        if (X > 0) & (np.abs(Y)<8.75):
            z = ('24+ ft.','Right Side(R)')
        elif (X < 0) & (np.abs(Y)<8.75):
            z = ('24+ ft.','Left Side(L)')
        elif (X > 0) & (np.abs(Y)>=8.75):
            z = ('24+ ft.','Right Side Center(RC)')
        elif (X < 0) & (np.abs(Y)>=8.75):
            z = ('24+ ft.','Left Side Center(LC)')
    if Y >= 40:
        z = ('Back Court Shot', 'Back Court(BC)')
    return z

# %%
def court(ax=None, color='black', lw=4, outer_lines=False,direction='up',short_three=False):
    '''
    Plots an NBA court
    outer_lines - accepts False or True. Plots the outer side lines of the court.
    direction - 'up' or 'down' depending on how you like to view the court
    Original function from http://savvastjortjoglou.com/
    '''
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        if direction=='up':
            ax = plt.gca(xlim = [-30,30],ylim = [43,-7],xticks=[],yticks=[],aspect=1.0)
            plt.text(22,44,'By: Doingthedishes',color='black',horizontalalignment='center',fontsize=20,fontweight='bold')
        elif direction=='down':
            ax = plt.gca(xlim = [30,-30],ylim = [-7,43],xticks=[],yticks=[],aspect=1.0)
            plt.text(-22,-7,'By: Doingthedishes',color='black',horizontalalignment='center',fontsize=20,fontweight='bold')
        else:
            ax = plt.gca()
    # Create the various parts of an NBA basketball court

    # Create the basketball hoop
    # Diameter of a hoop is 1.5 
    hoop = Circle((0, 0), radius=0.75, linewidth=lw/2, color=color, fill=False)

    # Create backboard
    backboard = Rectangle((-3, -0.75), 6, -0.1, linewidth=lw, color=color)

    # The paint
    # Create the outer box of the paint, width=16ft, height=19ft
    outer_box = Rectangle((-8, -5.25), 16, 19, linewidth=lw, color=color,
                          fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((-6, -5.25), 12, 19, linewidth=lw, color=color,
                          fill=False)

    # Create free throw top arc
    top_free_throw = Arc((0, 13.75), 12, 12, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((0, 13.75), 12, 12, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((0, 0), 8, 8, theta1=0, theta2=180, linewidth=lw,
                     color=color)

    # Three point line
    if not short_three:
        corner_three_a = Rectangle((-22, -5.25), 0, np.sqrt(23.75**2-22.0**2)+5.25, linewidth=lw,
                                   color=color)
        corner_three_b = Rectangle((22, -5.25), 0, np.sqrt(23.75**2-22.0**2)+5.25, linewidth=lw, color=color)
        # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
        three_arc = Arc((0, 0), 47.5, 47.5, theta1=np.arccos(22/23.75)*180/np.pi, theta2=180.0-np.arccos(22/23.75)*180/np.pi, linewidth=lw,
                        color=color)
    else:
        corner_three_a = Rectangle((-22, -5.25), 0, 5.25, linewidth=lw,
                           color=color)
        corner_three_b = Rectangle((22, -5.25), 0, 5.25, linewidth=lw, color=color)
        # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
        three_arc = Arc((0, 0), 44.0, 44.0, theta1=0, theta2=180, linewidth=lw,
                        color=color)
        # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box, inner_box, top_free_throw,
                      bottom_free_throw, restricted, corner_three_a,
                      corner_three_b, three_arc]  

    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((-25, -5.25), 50, 46.75, linewidth=lw,
                                color=color, fill=False)
        center_outer_arc = Arc((0, 41.25), 12, 12, theta1=180, theta2=0,
                                linewidth=lw, color=color)
        center_inner_arc = Arc((0, 41.25), 4, 4, theta1=180, theta2=0,
                                linewidth=lw, color=color)
        court_elements = court_elements + [outer_lines,center_outer_arc,center_inner_arc]
    else:
        ax.plot([-25,25],[-5.25,-5.25],linewidth=lw,color=color)
    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)
#    ax.axis('off')
    return ax

# %%
player_df = df[df['PLAYER_NAME']=='LeBron James']
player_df = player_area_pct(player_df)
player_df
# Out:
# SHOT_MADE_FLAG                                 0    1       FG%
# SEASON SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   16-24 ft.       Center(C)              43   23  0.348485
#                        Left Side Center(LC)   67   37  0.355769
#                        Left Side(L)           33   28  0.459016
#                        Right Side Center(RC)  70   53  0.430894
#                        Right Side(R)          28   18  0.391304
# ...                                           ..  ...       ...
# 2020   24+ ft.         Right Side(R)           5    3  0.375000
#        8-16 ft.        Center(C)              16   19  0.542857
#                        Left Side(L)           23   11  0.323529
#                        Right Side(R)          18   12  0.400000
#        Less Than 8 ft. Center(C)              90  218  0.707792
#
# [176 rows x 3 columns]

# %%
player_df = avg_shots_df.loc[2019]
tmp_null = player_df.copy()

# %%
shotchart = df[df['SEASON']==2019]
lShotchart = df[df['SEASON']==2009]

# %%
player_vs_league = (player_df.loc[:,'FG%'] - avg_shots_df.loc[2009].loc[:,'FG%'])*100 # compares player's FG% to league average
x,y = 0.1*shotchart.LOC_X.values, 0.1*shotchart.LOC_Y.values # get players shot coordinates
lx,ly = 0.1*lShotchart.LOC_X.values, 0.1*lShotchart.LOC_Y.values # get players shot coordinates

# get heetxbin to do the hard work for us. Use the extent and gridsize to get the desired bins
poly_hexbins = plt.hexbin(x,y, edgecolors='none', gridsize=35, extent=[-25,25,-6.25,50-6.25])

# get counts and vertices from histogram
counts = poly_hexbins.get_array()
verts = poly_hexbins.get_offsets()

league_poly_hexbins = plt.hexbin(lx,ly, edgecolors='face', gridsize=35, extent=[-25,25,-6.25,50-6.25])
league_counts = league_poly_hexbins.get_array()
league_verts = league_poly_hexbins.get_offsets()

# close figure since we are not interested in it
plt.close()

# %%
plt.figure(figsize=(12,10),facecolor='white')
ax = plt.gca(xlim = [30,-30],ylim = [-10,28],xticks=[],yticks=[],aspect=1.0)
court(ax,outer_lines=False,color='black',lw=4.0,direction='down')

plt.text(20.5, 22,'3 point line', fontsize=17)

plt.text(5, -4.7, 'Hoop', fontsize=17)
ax.annotate("", xy=(0, -1), xytext=(2, -3.8), arrowprops=dict(arrowstyle="->"))

plt.text(-9, 7, 'Restricted Area', fontsize=17)
ax.annotate("", xy=(-2, 3.8), xytext=(-9, 7), arrowprops=dict(arrowstyle="->"))

ax.axis('off')
ax.set_title("Basketball Court")
plt.savefig('C:/Users/User/OneDrive/Desktop/DSIP/NBAproject/graphs/2000_basketball_court.png',bbox_inches='tight');

# %%
# create figure plot
plt.figure(figsize=(12,10),facecolor='white') 
ax = plt.gca(xlim = [30,-30],ylim = [-10,40],xticks=[],yticks=[],aspect=1.0)
court(ax,outer_lines=False,color='black',lw=4.0,direction='down')
ax.axis('off')
ax.set_title("2009 vs 2019 shots")
 
s = 0.84 # scaling factor for hexagons

# FG% bins from -9 to 9. I'm using 200 bins to make the color scale more continous. This is my personal preference. 
# I think that this is not the case with the Grantland shot charts
bins = np.concatenate([[-np.inf],np.linspace(-9,9,200),[np.inf]]) 

# choose color scheme. I choose colors that are similar to the ones in Grantland
colors = [(0.06, 0.25, 0.66),(0.9,1.0,0.6), (0.8, 0, 0)]
cm = LinearSegmentedColormap.from_list('name', colors)
#cm = LinearSegmentedColormap.from_list('my_list', colors, N=len(bins)-1) # create linear color scheme

# create hexagons
xy = s*np.array([np.cos(np.linspace(np.pi/6,np.pi*330/180,6)),np.sin(np.linspace(np.pi/6,np.pi*330/180,6))]).T
b = np.zeros((6,2))
# adjust size scaling factor depending on the frequency of shots. Size-frequency relationship was choosen empirically 
counts_norm = np.zeros_like(counts)
counts_norm[(counts>=(league_counts+0.4*league_counts)) & (league_counts>10)] = 1 # 4 shots or more= full size hexagon
counts_norm[(counts>=(league_counts+0.2*league_counts)) & (counts<(league_counts+0.4*league_counts))] = 0.5 # 2 or 3 shots = half size hexagon 
counts_norm[(counts>(league_counts-0.1*league_counts)) & (counts<(league_counts+0.2*league_counts))] = 0.3 # 1 shot = small hexagon

# start creating patch and color list
patches=[]
colors=[]
# loop over vertices
for offc in range(verts.shape[0]):
    if counts_norm[offc] != 0:
        xc,yc = verts[offc][0],verts[offc][1] # vertex center 
        b[:,0] = xy[:,0]*counts_norm[offc] + xc # hexagon x coordinates
        b[:,1] = xy[:,1]*counts_norm[offc] + yc # hexagon y coordinates
        p_diff = player_vs_league.loc[shot_zone(xc,yc)] # FG% difference for the specific zone
        inds = np.digitize(p_diff*4, bins,right=True)-1 # convert FG% difference to color index  
        patches.append(Polygon(b))
        colors.append(inds)

# create colorbar 
for i in range(5):
    xc = 21-2*0.76*i
    yc = -8
    b[:,0] = xy[:,0] + xc
    b[:,1] = xy[:,1] + yc
    patches.append(Polygon(b))
    colors.append(i*50)
plt.text(21,-9.5,'Cold',horizontalalignment='center',verticalalignment='center')
plt.text(21-2*0.76*4,-9.5,'Hot',horizontalalignment='center',verticalalignment='center')

# create frequency illustration
xc = -14.5
yc = -8.0
plt.text(xc,-9.5,'Equal',horizontalalignment='center',verticalalignment='center')
b[:,0] = xy[:,0]*0.3 + xc
b[:,1] = xy[:,1]*0.3 + yc
patches.append(Polygon(b))
colors.append(100)
xc = -16
b[:,0] = xy[:,0]*0.50 + xc
b[:,1] = xy[:,1]*0.50 + yc
patches.append(Polygon(b))
colors.append(100)
xc = -18
b[:,0] = xy[:,0] + xc
b[:,1] = xy[:,1] + yc
plt.text(xc,-9.5,'+40%',horizontalalignment='center',verticalalignment='center')

patches.append(Polygon(b))
colors.append(100)

# plot all patches
p = PatchCollection(patches,cmap=cm,alpha=1)
p.set_array(np.array(colors))
ax.add_collection(p)
p.set_clim([0, len(bins)-1])
plt.savefig('C:/Users/User/OneDrive/Desktop/DSIP/NBAproject/graphs/2000_changing_popularity_2009vs2019.png')

# %%
group_df_pos = df[['SHOT_ZONE_AREA','SHOT_ZONE_RANGE','SHOT_DISTANCE','LOC_X','LOC_Y','SHOT_ATTEMPTED_FLAG','SHOT_MADE_FLAG','SEASON','POSITION']]
group_df_pos.head()
# Out:
#           SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  \
# 0  Right Side Center(RC)        16-24 ft.             18    106    151
# 1          Right Side(R)        16-24 ft.             17    171     47
# 2              Center(C)        16-24 ft.             17    -35    172
# 3              Center(C)  Less Than 8 ft.              2     21     -2
# 4              Center(C)  Less Than 8 ft.              7     -7     71
#
#    SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  SEASON POSITION
# 0                    1               0    2009        F
# 1                    1               1    2009        F
# 2                    1               0    2009        F
# 3                    1               1    2009        F
# 4                    1               0    2009        F

# %%
avg_shots_df_pos = group_df_pos.groupby(['SEASON', 'POSITION', 'SHOT_ZONE_RANGE', 'SHOT_ZONE_AREA']).sum()
avg_shots_df_pos.head()
# Out:
#                                                        SHOT_DISTANCE  LOC_X  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)                       1644    864
#                                 Left Side Center(LC)            1625  -9436
#                                 Left Side(L)                    1676 -16221
#                                 Right Side Center(RC)           1802  10285
#                                 Right Side(R)                   1388  13477
#
#                                                        LOC_Y  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)              16566
#                                 Left Side Center(LC)   13434
#                                 Left Side(L)            4585
#                                 Right Side Center(RC)  15012
#                                 Right Side(R)           3586
#
#                                                        SHOT_ATTEMPTED_FLAG  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)                               88
#                                 Left Side Center(LC)                    89
#                                 Left Side(L)                            92
#                                 Right Side Center(RC)                   97
#                                 Right Side(R)                           78
#
#                                                        SHOT_MADE_FLAG
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)                          39
#                                 Left Side Center(LC)               21
#                                 Left Side(L)                       37
#                                 Right Side Center(RC)              32
#                                 Right Side(R)                      34

# %%
player_df = avg_shots_df_pos.loc[2019]
tmp_null = player_df.copy()

# %%
league_area_pct(tmp_null)

# %%
player_df = tmp_null

# %%
shotchart = df[(df['POSITION']=='F') & (df['SEASON']==2019)]
lShotchart = df[(df['POSITION']=='F') & (df['SEASON']==2009)]

# %%
league_area_pct(avg_shots_df_pos)
avg_shots_df_pos
# Out:
#                                                        SHOT_DISTANCE   LOC_X  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)                       1644     864
#                                 Left Side Center(LC)            1625   -9436
#                                 Left Side(L)                    1676  -16221
#                                 Right Side Center(RC)           1802   10285
#                                 Right Side(R)                   1388   13477
# ...                                                              ...     ...
# 2020   G        8-16 ft.        Center(C)                      50819    2973
#                                 Left Side(L)                   24097 -204344
#                                 Right Side(R)                  24781  206284
#                 Back Court Shot Back Court(BC)                  5550    -256
#                 Less Than 8 ft. Center(C)                      51076   17761
#
#                                                         LOC_Y  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)               16566
#                                 Left Side Center(LC)    13434
#                                 Left Side(L)             4585
#                                 Right Side Center(RC)   15012
#                                 Right Side(R)            3586
# ...                                                       ...
# 2020   G        8-16 ft.        Center(C)              508458
#                                 Left Side(L)           118034
#                                 Right Side(R)          129423
#                 Back Court Shot Back Court(BC)          54444
#                 Less Than 8 ft. Center(C)              411844
#
#                                                        SHOT_ATTEMPTED_FLAG  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)                               88
#                                 Left Side Center(LC)                    89
#                                 Left Side(L)                            92
#                                 Right Side Center(RC)                   97
#                                 Right Side(R)                           78
# ...                                                                    ...
# 2020   G        8-16 ft.        Center(C)                             4467
#                                 Left Side(L)                          2106
#                                 Right Side(R)                         2181
#                 Back Court Shot Back Court(BC)                         105
#                 Less Than 8 ft. Center(C)                            21017
#
#                                                        SHOT_MADE_FLAG  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)                          39
#                                 Left Side Center(LC)               21
#                                 Left Side(L)                       37
#                                 Right Side Center(RC)              32
#                                 Right Side(R)                      34
# ...                                                               ...
# 2020   G        8-16 ft.        Center(C)                        1998
#                                 Left Side(L)                      895
#                                 Right Side(R)                     939
#                 Back Court Shot Back Court(BC)                      3
#                 Less Than 8 ft. Center(C)                       11888
#
#                                                             FG%
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)              0.443182
#                                 Left Side Center(LC)   0.235955
#                                 Left Side(L)           0.402174
#                                 Right Side Center(RC)  0.329897
#                                 Right Side(R)          0.435897
# ...                                                         ...
# 2020   G        8-16 ft.        Center(C)              0.447280
#                                 Left Side(L)           0.424976
#                                 Right Side(R)          0.430536
#                 Back Court Shot Back Court(BC)         0.028571
#                 Less Than 8 ft. Center(C)              0.565637
#
# [536 rows x 6 columns]

# %%
avg_shots_df_pos
# Out:
#                                                        SHOT_DISTANCE   LOC_X  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)                       1644     864
#                                 Left Side Center(LC)            1625   -9436
#                                 Left Side(L)                    1676  -16221
#                                 Right Side Center(RC)           1802   10285
#                                 Right Side(R)                   1388   13477
# ...                                                              ...     ...
# 2020   G        8-16 ft.        Center(C)                      50819    2973
#                                 Left Side(L)                   24097 -204344
#                                 Right Side(R)                  24781  206284
#                 Back Court Shot Back Court(BC)                  5550    -256
#                 Less Than 8 ft. Center(C)                      51076   17761
#
#                                                         LOC_Y  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)               16566
#                                 Left Side Center(LC)    13434
#                                 Left Side(L)             4585
#                                 Right Side Center(RC)   15012
#                                 Right Side(R)            3586
# ...                                                       ...
# 2020   G        8-16 ft.        Center(C)              508458
#                                 Left Side(L)           118034
#                                 Right Side(R)          129423
#                 Back Court Shot Back Court(BC)          54444
#                 Less Than 8 ft. Center(C)              411844
#
#                                                        SHOT_ATTEMPTED_FLAG  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)                               88
#                                 Left Side Center(LC)                    89
#                                 Left Side(L)                            92
#                                 Right Side Center(RC)                   97
#                                 Right Side(R)                           78
# ...                                                                    ...
# 2020   G        8-16 ft.        Center(C)                             4467
#                                 Left Side(L)                          2106
#                                 Right Side(R)                         2181
#                 Back Court Shot Back Court(BC)                         105
#                 Less Than 8 ft. Center(C)                            21017
#
#                                                        SHOT_MADE_FLAG  \
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)                          39
#                                 Left Side Center(LC)               21
#                                 Left Side(L)                       37
#                                 Right Side Center(RC)              32
#                                 Right Side(R)                      34
# ...                                                               ...
# 2020   G        8-16 ft.        Center(C)                        1998
#                                 Left Side(L)                      895
#                                 Right Side(R)                     939
#                 Back Court Shot Back Court(BC)                      3
#                 Less Than 8 ft. Center(C)                       11888
#
#                                                             FG%
# SEASON POSITION SHOT_ZONE_RANGE SHOT_ZONE_AREA
# 2009   C        16-24 ft.       Center(C)              0.443182
#                                 Left Side Center(LC)   0.235955
#                                 Left Side(L)           0.402174
#                                 Right Side Center(RC)  0.329897
#                                 Right Side(R)          0.435897
# ...                                                         ...
# 2020   G        8-16 ft.        Center(C)              0.447280
#                                 Left Side(L)           0.424976
#                                 Right Side(R)          0.430536
#                 Back Court Shot Back Court(BC)         0.028571
#                 Less Than 8 ft. Center(C)              0.565637
#
# [536 rows x 6 columns]

# %%
player_vs_league = (player_df.loc['F'].loc[:,'FG%'] - avg_shots_df_pos.loc[2009].loc['C'].loc[:,'FG%'])*100 # compares player's FG% to league average
x,y = 0.1*shotchart.LOC_X.values, 0.1*shotchart.LOC_Y.values # get players shot coordinates
lx,ly = 0.1*lShotchart.LOC_X.values, 0.1*lShotchart.LOC_Y.values # get players shot coordinates

# get heetxbin to do the hard work for us. Use the extent and gridsize to get the desired bins
poly_hexbins = plt.hexbin(x,y, edgecolors='none', gridsize=35, extent=[-25,25,-6.25,50-6.25])

# get counts and vertices from histogram
counts = poly_hexbins.get_array()
verts = poly_hexbins.get_offsets()

league_poly_hexbins = plt.hexbin(lx,ly, edgecolors='face', gridsize=35, extent=[-25,25,-6.25,50-6.25])
league_counts = league_poly_hexbins.get_array()
league_verts = league_poly_hexbins.get_offsets()

# close figure since we are not interested in it
plt.close()

# %%
# create figure plot
plt.figure(figsize=(12,10),facecolor='white') 
ax = plt.gca(xlim = [30,-30],ylim = [-10,40],xticks=[],yticks=[],aspect=1.0)
court(ax,outer_lines=False,color='black',lw=4.0,direction='down')
ax.axis('off')
 
s = 0.84 # scaling factor for hexagons

# FG% bins from -9 to 9. I'm using 200 bins to make the color scale more continous. This is my personal preference. 
# I think that this is not the case with the Grantland shot charts
bins = np.concatenate([[-np.inf],np.linspace(-9,9,200),[np.inf]]) 

# choose color scheme. I choose colors that are similar to the ones in Grantland
colors = [(0, 0.3, 0.8), (0.9,1.0,0.6), (0.8, 0, 0)]
cm = LinearSegmentedColormap.from_list('my_list', colors, N=len(bins)-1) # create linear color scheme

# create hexagons
xy = s*np.array([np.cos(np.linspace(np.pi/6,np.pi*330/180,6)),np.sin(np.linspace(np.pi/6,np.pi*330/180,6))]).T
b = np.zeros((6,2))
# adjust size scaling factor depending on the frequency of shots. Size-frequency relationship was choosen empirically 
counts_norm = np.zeros_like(counts)
counts_norm[(counts>=(league_counts+0.4*league_counts)) & (league_counts>10)] = 1 # 4 shots or more= full size hexagon
counts_norm[(counts>=(league_counts+0.2*league_counts)) & (counts<(league_counts+0.4*league_counts))] = 0.5 # 2 or 3 shots = half size hexagon 
counts_norm[(counts>(league_counts-0.1*league_counts)) & (counts<(league_counts+0.2*league_counts))] = 0.3 # 1 shot = small hexagon

# start creating patch and color list
patches=[]
colors=[]
# loop over vertices
for offc in range(verts.shape[0]):
    if counts_norm[offc] != 0:
        xc,yc = verts[offc][0],verts[offc][1] # vertex center 
        b[:,0] = xy[:,0]*counts_norm[offc] + xc # hexagon x coordinates
        b[:,1] = xy[:,1]*counts_norm[offc] + yc # hexagon y coordinates
        p_diff = player_vs_league.loc[shot_zone(xc,yc)] # FG% difference for the specific zone
        inds = np.digitize(p_diff, bins,right=True)-1 # convert FG% difference to color index  
        patches.append(Polygon(b))
        colors.append(inds)

# create colorbar 
for i in range(5):
    xc = 21-2*0.76*i
    yc = -8
    b[:,0] = xy[:,0] + xc
    b[:,1] = xy[:,1] + yc
    patches.append(Polygon(b))
    colors.append(i*50)
plt.text(21,-9.5,'Cold',horizontalalignment='center',verticalalignment='center')
plt.text(21-2*0.76*4,-9.5,'Hot',horizontalalignment='center',verticalalignment='center')

# create frequency illustration
xc = -14.5
yc = -8.0
plt.text(xc,-9.5,'Equal',horizontalalignment='center',verticalalignment='center')
b[:,0] = xy[:,0]*0.3 + xc
b[:,1] = xy[:,1]*0.3 + yc
patches.append(Polygon(b))
colors.append(100)
xc = -16
b[:,0] = xy[:,0]*0.50 + xc
b[:,1] = xy[:,1]*0.50 + yc
patches.append(Polygon(b))
colors.append(100)
xc = -18
b[:,0] = xy[:,0] + xc
b[:,1] = xy[:,1] + yc
plt.text(xc,-9.5,'+40%',horizontalalignment='center',verticalalignment='center')

patches.append(Polygon(b))
colors.append(100)

# plot all patches
p = PatchCollection(patches,cmap=cm,alpha=1)
p.set_array(np.array(colors))
ax.add_collection(p)
p.set_clim([0, len(bins)-1])

# %% [markdown]
# 2009 compared to 2019 ^

# %% [markdown]
# # Clear dataframes
# This project contains many dataframes. To make sure we don't run out of memory we will delete our dataframes at the end of each notebook.
