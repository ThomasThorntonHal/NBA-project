# %% [markdown]
# # Introduction
# This is the first of our _analysis_ notebooks. Instead of gathering, cleaning and preparing data we will instead be generating new data.
# In this notebook we will be finding the offensive and deffensive efficiency ratings of teams.
#
# ## Notebook Objective
# The main aim of this notebook is to calculate some advanced statistics which are frequently used in the NBA to assess the performance of teams. We will start by calculating the number of possesions each team had per game. We will use this to then calculate the offensive efficiency rating, the defensive efficiency and the net efficiency of each team for each season.
#
# ## Learning Objective
# The learning objective of this notebook is to learn about how the offensive, defensive and net efficiency of teams have changed over time.
# You can see the explanation of offensive efficiency [here](https://www.nbastuffer.com/analytics101/offensive-efficiency/#:~:text=Offensive%20efficiency%20is%20the%20number,team%20scores%20per%20100%20possessions.&text=In%20a%20game%3B%20%E2%80%9Coffensive%20efficiency,any%20season's%20offensive%20efficiency%20statistics.)

# %% [markdown]
# # Setup
#
# ## Imports

# %%
import pandas as pd

import numpy as np

import matplotlib.pylab as plt

# %% [markdown]
# # Parameters

# %%
# In
BASIC_GAME_DATASET = '../../data/processed/001_base_games.csv'
GAME_DETAILS_DATASET = '../../data/processed/010_details.csv'
TEAMS_DATASET = '../../data/raw/teams.csv'

# Out
EFFICIENCY_RATING_DATASET = '../../data/processed/110_team_efficiency.csv'
TEAM_SEASONAL_EFFICIENCY_DATASET = '../../data/processed/111_seasonal_efficiency.csv'

# %% [markdown]
# ## Configuration

# %%
# %matplotlib inline

# %% [markdown]
# # Load/Combine Datasets

# %% [markdown]
# ## Basic game data

# %%
basic_game = pd.read_csv(BASIC_GAME_DATASET, parse_dates=['GAME_DATE_EST'])
basic_game.shape, basic_game['GAME_ID'].nunique()
# Out:
# ((23421, 21), 23421)

# %%
basic_game.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2020-12-19  12000047            Final    1610612753       1610612766
# 1    2020-12-19  12000048            Final    1610612764       1610612765
# 2    2020-12-19  12000049            Final    1610612763       1610612737
# 3    2020-12-18  12000039            Final    1610612754       1610612755
# 4    2020-12-18  12000040            Final    1610612761       1610612748
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2020    1610612753     120.0        0.433        0.792  ...      23.0
# 1    2020    1610612764      99.0        0.427        0.625  ...      24.0
# 2    2020    1610612763     116.0        0.400        0.744  ...      21.0
# 3    2020    1610612754     107.0        0.371        0.692  ...      19.0
# 4    2020    1610612761     105.0        0.380        0.737  ...      27.0
#
#    REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0      50.0    1610612766     117.0        0.444        0.864         0.439
# 1      45.0    1610612765      96.0        0.402        0.647         0.326
# 2      43.0    1610612737     117.0        0.422        0.837         0.297
# 3      45.0    1610612755     113.0        0.533        0.629         0.355
# 4      37.0    1610612748     117.0        0.534        0.741         0.514
#
#    AST_away  REB_away  HOME_TEAM_WINS
# 0      21.0      52.0               1
# 1      18.0      51.0               1
# 2      24.0      47.0               0
# 3      23.0      48.0               0
# 4      30.0      51.0               0
#
# [5 rows x 21 columns]

# %%
basic_game.dtypes
# Out:
# GAME_DATE_EST       datetime64[ns]
# GAME_ID                      int64
# GAME_STATUS_TEXT            object
# HOME_TEAM_ID                 int64
# VISITOR_TEAM_ID              int64
# SEASON                       int64
# TEAM_ID_home                 int64
# PTS_home                   float64
# FG_PCT_home                float64
# FT_PCT_home                float64
# FG3_PCT_home               float64
# AST_home                   float64
# REB_home                   float64
# TEAM_ID_away                 int64
# PTS_away                   float64
# FG_PCT_away                float64
# FT_PCT_away                float64
# FG3_PCT_away               float64
# AST_away                   float64
# REB_away                   float64
# HOME_TEAM_WINS               int64
# dtype: object

# %% [markdown]
# ## Advanced game data

# %%
advanced_game = pd.read_csv(GAME_DETAILS_DATASET)
advanced_game.shape, advanced_game['GAME_ID'].nunique()
# Out:
# ((46843, 22), 23421)

# %%
advanced_game.head()
# Out:
#     GAME_ID     TEAM_ID   FGM   FGA    FG_PCT  FG3M  FG3A   FG3_PCT   FTM  \
# 0  10300001  1610612742  34.0  76.0  0.447368   2.0   8.0  0.250000  15.0
# 1  10300001  1610612762  32.0  70.0  0.457143   1.0   7.0  0.142857  25.0
# 2  10300002  1610612749  32.0  75.0  0.426667   2.0  13.0  0.153846  28.0
# 3  10300002  1610612763  40.0  81.0  0.493827   4.0  15.0  0.266667  21.0
# 4  10300003  1610612739  38.0  77.0  0.493506   4.0   6.0  0.666667  20.0
#
#     FTA  ...  DREB   REB   AST   STL  BLK    TO    PF    PTS  PLUS_MINUS  \
# 0  30.0  ...  26.0  38.0  20.0   9.0  4.0  18.0  34.0   85.0         0.0
# 1  34.0  ...  32.0  41.0  23.0   8.0  4.0  18.0  26.0   90.0         0.0
# 2  40.0  ...  32.0  43.0  20.0   9.0  4.0  24.0  26.0   94.0         0.0
# 3  34.0  ...  34.0  48.0  25.0  18.0  7.0  25.0  35.0  105.0         0.0
# 4  29.0  ...  40.0  52.0  25.0  10.0  7.0  25.0  33.0  100.0         0.0
#
#    SEASON
# 0    2003
# 1    2003
# 2    2003
# 3    2003
# 4    2003
#
# [5 rows x 22 columns]

# %%
advanced_game.dtypes
# Out:
# GAME_ID         int64
# TEAM_ID         int64
# FGM           float64
# FGA           float64
# FG_PCT        float64
# FG3M          float64
# FG3A          float64
# FG3_PCT       float64
# FTM           float64
# FTA           float64
# FT_PCT        float64
# OREB          float64
# DREB          float64
# REB           float64
# AST           float64
# STL           float64
# BLK           float64
# TO            float64
# PF            float64
# PTS           float64
# PLUS_MINUS    float64
# SEASON          int64
# dtype: object

# %% [markdown]
# # Offensive Efficiency
# Offensive efficiency is a widely used statistic in basketball. A teams offensive efficiency rating is the number of points a team is expected to score per 100 team possesions.
# ## Possessions
# Before we can calculate offensive efficiency rating we first need to calculate the number of possesions per game. Here is a simple, commonly used formula, to calculate a teams number of possesions in a game.<br>
# Possessions=0.96\*\[(Field Goal Attempts)+(Turnovers)+0.44*(Free Throw Attempts)-(Offensive Rebounds)\] <br><br>
# Here is an explanation of this formula from [NBA Stuffer](https://www.nbastuffer.com/analytics101/possession/):<br>
# "It counts as a team possession every time when a player of that team;
# <br>(1) attempts a field goal,
# <br>(2) misses a shot and does not get the offensive rebound,
# <br>(3) turns the ball over (some sources add “turnovers that are assigned to teams” for a more precise possession calculation),
# <br>(4) goes to the line for two or three shots and either makes the last shot or does not get the rebound of a missed last shot."
# <br><br>NBA Stuffer also explains where the 0.44 and 0.96 comes from:<br>
# ".44 multiplier has to be taken into account because not all free throws take up a possession... Research has determined that about 44% of all free throws take up possessions. The .96 multiplier accounts for team offensive rebounds in situations where a missed shot is tipped out of bounds by a defensive player, continuing the possession without an offensive rebound being credited."

# %%
advanced_game['POSSESSIONS'] = round(0.96*(advanced_game['FGA'] + advanced_game['TO'] + 0.44*advanced_game['FTA'] - advanced_game['OREB']) )
advanced_game.head(5)
# Out:
#     GAME_ID     TEAM_ID   FGM   FGA    FG_PCT  FG3M  FG3A   FG3_PCT   FTM  \
# 0  10300001  1610612742  34.0  76.0  0.447368   2.0   8.0  0.250000  15.0
# 1  10300001  1610612762  32.0  70.0  0.457143   1.0   7.0  0.142857  25.0
# 2  10300002  1610612749  32.0  75.0  0.426667   2.0  13.0  0.153846  28.0
# 3  10300002  1610612763  40.0  81.0  0.493827   4.0  15.0  0.266667  21.0
# 4  10300003  1610612739  38.0  77.0  0.493506   4.0   6.0  0.666667  20.0
#
#     FTA  ...   REB   AST   STL  BLK    TO    PF    PTS  PLUS_MINUS  SEASON  \
# 0  30.0  ...  38.0  20.0   9.0  4.0  18.0  34.0   85.0         0.0    2003
# 1  34.0  ...  41.0  23.0   8.0  4.0  18.0  26.0   90.0         0.0    2003
# 2  40.0  ...  43.0  20.0   9.0  4.0  24.0  26.0   94.0         0.0    2003
# 3  34.0  ...  48.0  25.0  18.0  7.0  25.0  35.0  105.0         0.0    2003
# 4  29.0  ...  52.0  25.0  10.0  7.0  25.0  33.0  100.0         0.0    2003
#
#    POSSESSIONS
# 0         91.0
# 1         90.0
# 2        101.0
# 3        103.0
# 4         99.0
#
# [5 rows x 23 columns]

# %% [markdown]
# Now that possessions have been calculated it is very simple to find offensive efficiency rating. First we find points per possession(PPP) then multiply this by 100 to get offensive efficiency rating(OER).

# %%
advanced_game['PPP'] = advanced_game['PTS']/advanced_game['POSSESSIONS']
advanced_game.head(5)
# Out:
#     GAME_ID     TEAM_ID   FGM   FGA    FG_PCT  FG3M  FG3A   FG3_PCT   FTM  \
# 0  10300001  1610612742  34.0  76.0  0.447368   2.0   8.0  0.250000  15.0
# 1  10300001  1610612762  32.0  70.0  0.457143   1.0   7.0  0.142857  25.0
# 2  10300002  1610612749  32.0  75.0  0.426667   2.0  13.0  0.153846  28.0
# 3  10300002  1610612763  40.0  81.0  0.493827   4.0  15.0  0.266667  21.0
# 4  10300003  1610612739  38.0  77.0  0.493506   4.0   6.0  0.666667  20.0
#
#     FTA  ...   AST   STL  BLK    TO    PF    PTS  PLUS_MINUS  SEASON  \
# 0  30.0  ...  20.0   9.0  4.0  18.0  34.0   85.0         0.0    2003
# 1  34.0  ...  23.0   8.0  4.0  18.0  26.0   90.0         0.0    2003
# 2  40.0  ...  20.0   9.0  4.0  24.0  26.0   94.0         0.0    2003
# 3  34.0  ...  25.0  18.0  7.0  25.0  35.0  105.0         0.0    2003
# 4  29.0  ...  25.0  10.0  7.0  25.0  33.0  100.0         0.0    2003
#
#    POSSESSIONS       PPP
# 0         91.0  0.934066
# 1         90.0  1.000000
# 2        101.0  0.930693
# 3        103.0  1.019417
# 4         99.0  1.010101
#
# [5 rows x 24 columns]

# %%
advanced_game['OER'] = 100*advanced_game['PPP']
advanced_game.head(5)
# Out:
#     GAME_ID     TEAM_ID   FGM   FGA    FG_PCT  FG3M  FG3A   FG3_PCT   FTM  \
# 0  10300001  1610612742  34.0  76.0  0.447368   2.0   8.0  0.250000  15.0
# 1  10300001  1610612762  32.0  70.0  0.457143   1.0   7.0  0.142857  25.0
# 2  10300002  1610612749  32.0  75.0  0.426667   2.0  13.0  0.153846  28.0
# 3  10300002  1610612763  40.0  81.0  0.493827   4.0  15.0  0.266667  21.0
# 4  10300003  1610612739  38.0  77.0  0.493506   4.0   6.0  0.666667  20.0
#
#     FTA  ...   STL  BLK    TO    PF    PTS  PLUS_MINUS  SEASON  POSSESSIONS  \
# 0  30.0  ...   9.0  4.0  18.0  34.0   85.0         0.0    2003         91.0
# 1  34.0  ...   8.0  4.0  18.0  26.0   90.0         0.0    2003         90.0
# 2  40.0  ...   9.0  4.0  24.0  26.0   94.0         0.0    2003        101.0
# 3  34.0  ...  18.0  7.0  25.0  35.0  105.0         0.0    2003        103.0
# 4  29.0  ...  10.0  7.0  25.0  33.0  100.0         0.0    2003         99.0
#
#         PPP         OER
# 0  0.934066   93.406593
# 1  1.000000  100.000000
# 2  0.930693   93.069307
# 3  1.019417  101.941748
# 4  1.010101  101.010101
#
# [5 rows x 25 columns]

# %% [markdown]
# # Defensive Efficiency
# Defensive Efficiency is calculated in a similar way to offensive efficiency. Defensive Efficiency Rating is the number of points a team allows per 100 possesions. The lower a teams DER, the better.
# ## Add home and away data to Efficiency dataset
# To find the number of points the opponent scored we need to merge our base game dataset to our advanced game dataset. The only columns we need to take from base game are 'PTS_home' and 'PTS_away' but we'll add in 'GAME_DATE_EST' just in case we ever want to find the date of certain games.

# %%
efficiency = advanced_game.merge(basic_game[['GAME_ID','GAME_DATE_EST', 'PTS_home', 'PTS_away']], how='inner', on=['GAME_ID'])

# The resulting df should be no larger than the advanced_game df.
assert len(efficiency)<= len(advanced_game)

efficiency.shape, efficiency['GAME_ID'].nunique()
# Out:
# ((46843, 28), 23421)

# %%
efficiency.head()
# Out:
#     GAME_ID     TEAM_ID   FGM   FGA    FG_PCT  FG3M  FG3A   FG3_PCT   FTM  \
# 0  10300001  1610612742  34.0  76.0  0.447368   2.0   8.0  0.250000  15.0
# 1  10300001  1610612762  32.0  70.0  0.457143   1.0   7.0  0.142857  25.0
# 2  10300002  1610612749  32.0  75.0  0.426667   2.0  13.0  0.153846  28.0
# 3  10300002  1610612763  40.0  81.0  0.493827   4.0  15.0  0.266667  21.0
# 4  10300003  1610612739  38.0  77.0  0.493506   4.0   6.0  0.666667  20.0
#
#     FTA  ...    PF    PTS  PLUS_MINUS  SEASON  POSSESSIONS       PPP  \
# 0  30.0  ...  34.0   85.0         0.0    2003         91.0  0.934066
# 1  34.0  ...  26.0   90.0         0.0    2003         90.0  1.000000
# 2  40.0  ...  26.0   94.0         0.0    2003        101.0  0.930693
# 3  34.0  ...  35.0  105.0         0.0    2003        103.0  1.019417
# 4  29.0  ...  33.0  100.0         0.0    2003         99.0  1.010101
#
#           OER  GAME_DATE_EST  PTS_home  PTS_away
# 0   93.406593     2003-10-05      90.0      85.0
# 1  100.000000     2003-10-05      90.0      85.0
# 2   93.069307     2003-10-06     105.0      94.0
# 3  101.941748     2003-10-06     105.0      94.0
# 4  101.010101     2003-10-07      96.0     100.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Add opponents points
# We can now use this data to find the number of points the opponent scored in the game.

# %%
for index,game in efficiency.iterrows():
    if game['PTS'] == game['PTS_home']:
        efficiency.loc[index,'OPP_PTS'] = game['PTS_away']
        efficiency.loc[index,'HOME'] = True
    else:
        efficiency.loc[index,'OPP_PTS'] = game['PTS_home']
        efficiency.loc[index,'HOME'] = False

# %%
efficiency.head()
# Out:
#     GAME_ID     TEAM_ID   FGM   FGA    FG_PCT  FG3M  FG3A   FG3_PCT   FTM  \
# 0  10300001  1610612742  34.0  76.0  0.447368   2.0   8.0  0.250000  15.0
# 1  10300001  1610612762  32.0  70.0  0.457143   1.0   7.0  0.142857  25.0
# 2  10300002  1610612749  32.0  75.0  0.426667   2.0  13.0  0.153846  28.0
# 3  10300002  1610612763  40.0  81.0  0.493827   4.0  15.0  0.266667  21.0
# 4  10300003  1610612739  38.0  77.0  0.493506   4.0   6.0  0.666667  20.0
#
#     FTA  ...  PLUS_MINUS  SEASON  POSSESSIONS       PPP         OER  \
# 0  30.0  ...         0.0    2003         91.0  0.934066   93.406593
# 1  34.0  ...         0.0    2003         90.0  1.000000  100.000000
# 2  40.0  ...         0.0    2003        101.0  0.930693   93.069307
# 3  34.0  ...         0.0    2003        103.0  1.019417  101.941748
# 4  29.0  ...         0.0    2003         99.0  1.010101  101.010101
#
#    GAME_DATE_EST  PTS_home  PTS_away  OPP_PTS   HOME
# 0     2003-10-05      90.0      85.0     90.0  False
# 1     2003-10-05      90.0      85.0     85.0   True
# 2     2003-10-06     105.0      94.0    105.0  False
# 3     2003-10-06     105.0      94.0     94.0   True
# 4     2003-10-07      96.0     100.0     96.0  False
#
# [5 rows x 30 columns]

# %% [markdown]
# Now we can add the opponent team's OER as OER_OPP which will be changed to DER

# %%
proper_eff = efficiency.merge(efficiency[['GAME_ID', 'OPP_PTS', 'OER', 'POSSESSIONS']], how='inner', left_on=['GAME_ID', 'PTS'],
                                 right_on=['GAME_ID', 'OPP_PTS'], suffixes=(None, '_OPP'))

proper_eff.shape, proper_eff['GAME_ID'].nunique()
# Out:
# ((46724, 33), 23379)

# %%
proper_eff
# Out:
#         GAME_ID     TEAM_ID   FGM   FGA    FG_PCT  FG3M  FG3A   FG3_PCT   FTM  \
# 0      10300001  1610612742  34.0  76.0  0.447368   2.0   8.0  0.250000  15.0
# 1      10300001  1610612762  32.0  70.0  0.457143   1.0   7.0  0.142857  25.0
# 2      10300002  1610612749  32.0  75.0  0.426667   2.0  13.0  0.153846  28.0
# 3      10300002  1610612763  40.0  81.0  0.493827   4.0  15.0  0.266667  21.0
# 4      10300003  1610612739  38.0  77.0  0.493506   4.0   6.0  0.666667  20.0
# ...         ...         ...   ...   ...       ...   ...   ...       ...   ...
# 46719  41900405  1610612748  38.0  83.0  0.457831  14.0  33.0  0.424242  21.0
# 46720  41900406  1610612747  43.0  89.0  0.483146  11.0  35.0  0.314286   9.0
# 46721  41900406  1610612748  35.0  79.0  0.443038  10.0  28.0  0.357143  13.0
# 46722  51900111  1610612757  38.0  84.0  0.452381  15.0  40.0  0.375000  35.0
# 46723  51900111  1610612763  45.0  92.0  0.489130  14.0  25.0  0.560000  18.0
#
#         FTA  ...       PPP         OER  GAME_DATE_EST  PTS_home  PTS_away  \
# 0      30.0  ...  0.934066   93.406593     2003-10-05      90.0      85.0
# 1      34.0  ...  1.000000  100.000000     2003-10-05      90.0      85.0
# 2      40.0  ...  0.930693   93.069307     2003-10-06     105.0      94.0
# 3      34.0  ...  1.019417  101.941748     2003-10-06     105.0      94.0
# 4      29.0  ...  1.010101  101.010101     2003-10-07      96.0     100.0
# ...     ...  ...       ...         ...            ...       ...       ...
# 46719  22.0  ...  1.193548  119.354839     2020-10-09     108.0     111.0
# 46720  14.0  ...  1.164835  116.483516     2020-10-11      93.0     106.0
# 46721  22.0  ...  1.044944  104.494382     2020-10-11      93.0     106.0
# 46722  41.0  ...  1.235294  123.529412     2020-08-15     126.0     122.0
# 46723  22.0  ...  1.184466  118.446602     2020-08-15     126.0     122.0
#
#        OPP_PTS   HOME  OPP_PTS_OPP     OER_OPP  POSSESSIONS_OPP
# 0         90.0  False         85.0  100.000000             90.0
# 1         85.0   True         90.0   93.406593             91.0
# 2        105.0  False         94.0  101.941748            103.0
# 3         94.0   True        105.0   93.069307            101.0
# 4         96.0  False        100.0   95.049505            101.0
# ...        ...    ...          ...         ...              ...
# 46719    108.0  False        111.0  120.000000             90.0
# 46720     93.0  False        106.0  104.494382             89.0
# 46721    106.0   True         93.0  116.483516             91.0
# 46722    122.0   True        126.0  118.446602            103.0
# 46723    126.0  False        122.0  123.529412            102.0
#
# [46724 rows x 33 columns]

# %% [markdown]
# We can now remove some unwanted columns

# %%
proper_eff.columns
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT',
#        'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
#        'TO', 'PF', 'PTS', 'PLUS_MINUS', 'SEASON', 'POSSESSIONS', 'PPP', 'OER',
#        'GAME_DATE_EST', 'PTS_home', 'PTS_away', 'OPP_PTS', 'HOME',
#        'OPP_PTS_OPP', 'OER_OPP', 'POSSESSIONS_OPP'],
#       dtype='object')

# %%
cleaned_efficiency = proper_eff.copy()
cleaned_efficiency.drop(columns=['PTS_home', 'PTS_away', 'PLUS_MINUS', 'OPP_PTS_OPP'], inplace=True)
cleaned_efficiency.head()
# Out:
#     GAME_ID     TEAM_ID   FGM   FGA    FG_PCT  FG3M  FG3A   FG3_PCT   FTM  \
# 0  10300001  1610612742  34.0  76.0  0.447368   2.0   8.0  0.250000  15.0
# 1  10300001  1610612762  32.0  70.0  0.457143   1.0   7.0  0.142857  25.0
# 2  10300002  1610612749  32.0  75.0  0.426667   2.0  13.0  0.153846  28.0
# 3  10300002  1610612763  40.0  81.0  0.493827   4.0  15.0  0.266667  21.0
# 4  10300003  1610612739  38.0  77.0  0.493506   4.0   6.0  0.666667  20.0
#
#     FTA  ...    PTS  SEASON  POSSESSIONS       PPP         OER  GAME_DATE_EST  \
# 0  30.0  ...   85.0    2003         91.0  0.934066   93.406593     2003-10-05
# 1  34.0  ...   90.0    2003         90.0  1.000000  100.000000     2003-10-05
# 2  40.0  ...   94.0    2003        101.0  0.930693   93.069307     2003-10-06
# 3  34.0  ...  105.0    2003        103.0  1.019417  101.941748     2003-10-06
# 4  29.0  ...  100.0    2003         99.0  1.010101  101.010101     2003-10-07
#
#    OPP_PTS   HOME     OER_OPP  POSSESSIONS_OPP
# 0     90.0  False  100.000000             90.0
# 1     85.0   True   93.406593             91.0
# 2    105.0  False  101.941748            103.0
# 3     94.0   True   93.069307            101.0
# 4     96.0  False   95.049505            101.0
#
# [5 rows x 29 columns]

# %% [markdown]
# I want to rearrange the columns in to an order that makes more sense to me.

# %%
cleaned_efficiency.columns
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT',
#        'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
#        'TO', 'PF', 'PTS', 'SEASON', 'POSSESSIONS', 'PPP', 'OER',
#        'GAME_DATE_EST', 'OPP_PTS', 'HOME', 'OER_OPP', 'POSSESSIONS_OPP'],
#       dtype='object')

# %%
columns_order = ['GAME_DATE_EST', 'SEASON', 'GAME_ID', 'TEAM_ID', 'HOME', 
                 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
                 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO',
                 'PF', 'PTS', 'POSSESSIONS', 'PPP', 'OER', 'OPP_PTS', 'OER_OPP', 'POSSESSIONS_OPP']

# %%
cleaned_efficiency = cleaned_efficiency[columns_order]
cleaned_efficiency.head()
# Out:
#   GAME_DATE_EST  SEASON   GAME_ID     TEAM_ID   HOME   FGM   FGA    FG_PCT  \
# 0    2003-10-05    2003  10300001  1610612742  False  34.0  76.0  0.447368
# 1    2003-10-05    2003  10300001  1610612762   True  32.0  70.0  0.457143
# 2    2003-10-06    2003  10300002  1610612749  False  32.0  75.0  0.426667
# 3    2003-10-06    2003  10300002  1610612763   True  40.0  81.0  0.493827
# 4    2003-10-07    2003  10300003  1610612739  False  38.0  77.0  0.493506
#
#    FG3M  FG3A  ...  BLK    TO    PF    PTS  POSSESSIONS       PPP         OER  \
# 0   2.0   8.0  ...  4.0  18.0  34.0   85.0         91.0  0.934066   93.406593
# 1   1.0   7.0  ...  4.0  18.0  26.0   90.0         90.0  1.000000  100.000000
# 2   2.0  13.0  ...  4.0  24.0  26.0   94.0        101.0  0.930693   93.069307
# 3   4.0  15.0  ...  7.0  25.0  35.0  105.0        103.0  1.019417  101.941748
# 4   4.0   6.0  ...  7.0  25.0  33.0  100.0         99.0  1.010101  101.010101
#
#    OPP_PTS     OER_OPP  POSSESSIONS_OPP
# 0     90.0  100.000000             90.0
# 1     85.0   93.406593             91.0
# 2    105.0  101.941748            103.0
# 3     94.0   93.069307            101.0
# 4     96.0   95.049505            101.0
#
# [5 rows x 29 columns]

# %% [markdown]
# We can now convert the OER_OPP to defensive efficiency rating (DER). This is because a teams DER is equivalent to their opponents OER.

# %%
cleaned_efficiency.rename(columns={'OER_OPP': 'DER'}, inplace=True)
cleaned_efficiency.head(5)
# Out:
#   GAME_DATE_EST  SEASON   GAME_ID     TEAM_ID   HOME   FGM   FGA    FG_PCT  \
# 0    2003-10-05    2003  10300001  1610612742  False  34.0  76.0  0.447368
# 1    2003-10-05    2003  10300001  1610612762   True  32.0  70.0  0.457143
# 2    2003-10-06    2003  10300002  1610612749  False  32.0  75.0  0.426667
# 3    2003-10-06    2003  10300002  1610612763   True  40.0  81.0  0.493827
# 4    2003-10-07    2003  10300003  1610612739  False  38.0  77.0  0.493506
#
#    FG3M  FG3A  ...  BLK    TO    PF    PTS  POSSESSIONS       PPP         OER  \
# 0   2.0   8.0  ...  4.0  18.0  34.0   85.0         91.0  0.934066   93.406593
# 1   1.0   7.0  ...  4.0  18.0  26.0   90.0         90.0  1.000000  100.000000
# 2   2.0  13.0  ...  4.0  24.0  26.0   94.0        101.0  0.930693   93.069307
# 3   4.0  15.0  ...  7.0  25.0  35.0  105.0        103.0  1.019417  101.941748
# 4   4.0   6.0  ...  7.0  25.0  33.0  100.0         99.0  1.010101  101.010101
#
#    OPP_PTS         DER  POSSESSIONS_OPP
# 0     90.0  100.000000             90.0
# 1     85.0   93.406593             91.0
# 2    105.0  101.941748            103.0
# 3     94.0   93.069307            101.0
# 4     96.0   95.049505            101.0
#
# [5 rows x 29 columns]

# %% [markdown]
# # Net Efficiency

# %% [markdown]
# Finally we can get a teams Net Efficiency Rating (NER). This is simply a teams OER - DER.

# %%
cleaned_efficiency['NER'] = cleaned_efficiency['OER'] - cleaned_efficiency['DER']
cleaned_efficiency.head(5)
# Out:
#   GAME_DATE_EST  SEASON   GAME_ID     TEAM_ID   HOME   FGM   FGA    FG_PCT  \
# 0    2003-10-05    2003  10300001  1610612742  False  34.0  76.0  0.447368
# 1    2003-10-05    2003  10300001  1610612762   True  32.0  70.0  0.457143
# 2    2003-10-06    2003  10300002  1610612749  False  32.0  75.0  0.426667
# 3    2003-10-06    2003  10300002  1610612763   True  40.0  81.0  0.493827
# 4    2003-10-07    2003  10300003  1610612739  False  38.0  77.0  0.493506
#
#    FG3M  FG3A  ...    TO    PF    PTS  POSSESSIONS       PPP         OER  \
# 0   2.0   8.0  ...  18.0  34.0   85.0         91.0  0.934066   93.406593
# 1   1.0   7.0  ...  18.0  26.0   90.0         90.0  1.000000  100.000000
# 2   2.0  13.0  ...  24.0  26.0   94.0        101.0  0.930693   93.069307
# 3   4.0  15.0  ...  25.0  35.0  105.0        103.0  1.019417  101.941748
# 4   4.0   6.0  ...  25.0  33.0  100.0         99.0  1.010101  101.010101
#
#    OPP_PTS         DER  POSSESSIONS_OPP       NER
# 0     90.0  100.000000             90.0 -6.593407
# 1     85.0   93.406593             91.0  6.593407
# 2    105.0  101.941748            103.0 -8.872441
# 3     94.0   93.069307            101.0  8.872441
# 4     96.0   95.049505            101.0  5.960596
#
# [5 rows x 30 columns]

# %% [markdown]
# These statistics are not very enlightening in a single game but over a season they can give us a very good idea of how teams performed. To make things easier to read we first want to add team names to our dataset.

# %%
teams = pd.read_csv(TEAMS_DATASET).set_index(['TEAM_ID'])
teams.shape
# Out:
# (30, 13)

# %%
teams.head()
# Out:
#             LEAGUE_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# TEAM_ID
# 1610612737          0      1949      2019          ATL      Hawks
# 1610612738          0      1946      2019          BOS    Celtics
# 1610612740          0      2002      2019          NOP   Pelicans
# 1610612741          0      1966      2019          CHI      Bulls
# 1610612742          0      1980      2019          DAL  Mavericks
#
#             YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# TEAM_ID
# 1610612737         1949      Atlanta          State Farm Arena        18729.0
# 1610612738         1946       Boston                 TD Garden        18624.0
# 1610612740         2002  New Orleans      Smoothie King Center            NaN
# 1610612741         1966      Chicago             United Center        21711.0
# 1610612742         1980       Dallas  American Airlines Center        19200.0
#
#                       OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# TEAM_ID
# 1610612737     Tony Ressler  Travis Schlenk   Lloyd Pierce      Erie Bayhawks
# 1610612738    Wyc Grousbeck     Danny Ainge   Brad Stevens    Maine Red Claws
# 1610612740       Tom Benson  Trajan Langdon   Alvin Gentry       No Affiliate
# 1610612741  Jerry Reinsdorf      Gar Forman     Jim Boylen   Windy City Bulls
# 1610612742       Mark Cuban   Donnie Nelson  Rick Carlisle      Texas Legends

# %%
team_dict = {}
for team in teams.iterrows():
    team_dict[team[0]] = team[1]['NICKNAME']
team_dict
# Out:
# {1610612737: 'Hawks',
#  1610612738: 'Celtics',
#  1610612740: 'Pelicans',
#  1610612741: 'Bulls',
#  1610612742: 'Mavericks',
#  1610612743: 'Nuggets',
#  1610612745: 'Rockets',
#  1610612746: 'Clippers',
#  1610612747: 'Lakers',
#  1610612748: 'Heat',
#  1610612749: 'Bucks',
#  1610612750: 'Timberwolves',
#  1610612751: 'Nets',
#  1610612752: 'Knicks',
#  1610612753: 'Magic',
#  1610612754: 'Pacers',
#  1610612755: '76ers',
#  1610612756: 'Suns',
#  1610612757: 'Trail Blazers',
#  1610612758: 'Kings',
#  1610612759: 'Spurs',
#  1610612760: 'Thunder',
#  1610612761: 'Raptors',
#  1610612762: 'Jazz',
#  1610612763: 'Grizzlies',
#  1610612764: 'Wizards',
#  1610612765: 'Pistons',
#  1610612766: 'Hornets',
#  1610612739: 'Cavaliers',
#  1610612744: 'Warriors'}

# %%
cleaned_efficiency['TEAM_NAME'] = cleaned_efficiency['TEAM_ID'].map(team_dict)

# %%
season_cleaned_efficiency = cleaned_efficiency.groupby(['SEASON', 'TEAM_ID', 'TEAM_NAME']).sum()
season_cleaned_efficiency
# Out:
#                                 GAME_ID     FGM     FGA     FG_PCT   FG3M  \
# SEASON TEAM_ID    TEAM_NAME
# 2003   1610612737 Haw
# SEASON TEAM_ID    TEAM_NAME
# 2003   1610612737 Hawks               7471.0 -421.109263
#        1610612738 Celtics             7986.0 -148.174321
#        1610612739 Cavaliers           7569.0 -251.563685
#        1610612740 Pelicans            7798.0  -55.342431
#        1610612741 Bulls               7436.0 -565.952069
# ...                                      ...         ...
# 2020   1610612762 Jazz                 293.0   52.289404
#        1610612763 Grizzlies            434.0   39.364711
#        1610612764 Wizards              302.0  -20.216548
#        1610612765 Pistons              403.0   12.843683
#        1610612766 Hornets              425.0   -5.772024
#
# [539 rows x 26 columns]

# %%
season_cleaned_efficiency.columns
# Out:
# Index(['GAME_ID', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF',
#        'PTS', 'POSSESSIONS', 'PPP', 'OER', 'OPP_PTS', 'DER', 'POSSESSIONS_OPP',
#        'NER'],
#       dtype='object')

# %% [markdown]
# Beacause we used the sum operation with _groupby()_ we now need to correct all columns that were calculated with multiplication or division. This includes FG_PCT, FG3_PCT, FT_PCT, PPP, OER, DER and NER. We can write a function to do this.

# %%
def percentage_correction(dataframe):
    dataframe['FG_PCT'] = dataframe['FGM']/dataframe['FGA']
    dataframe['FG3_PCT'] = dataframe['FG3M']/dataframe['FG3A']
    dataframe['FT_PCT'] = dataframe['FTM']/dataframe['FTA']
    dataframe['PPP'] = dataframe['PTS']/dataframe['POSSESSIONS']
    dataframe['OER'] = 100*dataframe['PPP']
    dataframe['OPP_PPP'] = dataframe['OPP_PTS']/dataframe['POSSESSIONS_OPP']
    dataframe['DER'] = 100*dataframe['OPP_PPP']
    dataframe['NER'] = dataframe['OER'] - dataframe['DER']

# %%
percentage_correction(season_cleaned_efficiency)
season_cleaned_efficiency
# Out:
#                                 GAME_ID     FGM     FGA    FG_PCT   FG3M  \
# SEASON TEAM_ID    TEAM_NAME
# 2003   1610612737 Hawks      1674947672  2857.0  6609.0  0.432289  422.0
#        1610612738 Celtics    1836147889  2994.0  6775.0  0.441919  577.0
#        1610612739 Cavaliers  1685248550  2992.0  6903.0  0.433435  254.0
#        1610612740 Pelicans   1946749139  2977.0  7139.0  0.417005  572.0
#        1610612741 Bulls      1654647953  2781.0  6721.0  0.413778  425.0
# ...                                 ...     ...     ...       ...    ...
# 2020   1610612762 Jazz         36000073   118.0   248.0  0.475806   53.0
#        1610612763 Grizzlies    48000117   166.0   368.0  0.451087   60.0
#        1610612764 Wizards      36000095   111.0   264.0  0.420455   36.0
#        1610612765 Pistons      48000098   132.0   322.0  0.409938   49.0
#        1610612766 Hornets      48000105   157.0   353.0  0.444759   58.0
#
#                                FG3A   FG3_PCT     FTM     FTA    FT_PCT  ...  \
# SEASON TEAM_ID    TEAM_NAME                                              ...
# 2003   1610612737 Hawks      1256.0  0.335987  1555.0  2004.0  0.775948  ...
#        1610612738 Celtics    1676.0  0.344272  1673.0  2229.0  0.750561  ...
#        1610612739 Cavaliers   804.0  0.315920  1564.0  2087.0  0.749401  ...
#        1610612740 Pelicans   1796.0  0.318486  1567.0  2082.0  0.752642  ...
#        1610612741 Bulls      1241.0  0.342466  1329.0  1835.0  0.724251  ...
# ...                             ...       ...     ...     ...       ...  ...
# 2020   1610612762 Jazz        132.0  0.401515    66.0    83.0  0.795181  ...
#        1610612763 Grizzlies   171.0  0.350877    82.0   115.0  0.713043  ...
#        1610612764 Wizards     115.0  0.313043    41.0    60.0  0.683333  ...
#        1610612765 Pistons     150.0  0.326667    63.0    88.0  0.715909  ...
#        1610612766 Hornets     147.0  0.394558    77.0   105.0  0.733333  ...
#
#                                  PF     PTS  POSSESSIONS       PPP  \
# SEASON TEAM_ID    TEAM_NAME
# 2003   1610612737 Haw
# 1610612764 Wizards         9519.0       8795.0  1.082319  108.231950   9582.0
# 1610612765 Pistons        10188.0       9481.0  1.074570  107.457019   9735.0
# 1610612766 Hornets         7698.0       7506.0  1.025580  102.557954   8178.0
#
#                                  DER  POSSESSIONS_OPP        NER   OPP_PPP
# TEAM_ID    TEAM_NAME
# 1610612737 Hawks          113.505747           7308.0 -10.714668  1.135057
# 1610612738 Celtics        108.031496           8255.0   1.190686  1.080315
# 1610612739 Cavaliers      107.529758           7477.0   0.872704  1.075298
# 1610612740 Pelicans       110.634697           7090.0  -9.479512  1.106347
# 1610612741 Bulls          102.609974           8161.0   0.500103  1.026100
# 1610612742 Mavericks      107.630878           9016.0   5.177386  1.076309
# 1610612743 Nuggets        105.671786           8269.0   1.965590  1.056718
# 1610612744 Warriors       108.800937           7681.0  -2.563931  1.088009
# 1610612745 Rockets        105.338757           7867.0   3.320461  1.053388
# 1610612746 Clippers       108.960087           7366.0  -1.566722  1.089601
# 1610612747 Lakers         113.181068           7268.0  -2.988495  1.131811
# 1610612748 Heat           104.820111           8672.0   7.880891  1.048201
# 1610612749 Bucks          111.028603           7272.0  -3.196531  1.110286
# 1610612750 Timberwolves   108.150304           7558.0   1.428088  1.081503
# 1610612751 Nets           105.531179           7521.0  -2.493238  1.055312
# 1610612752 Knicks         111.281096           7517.0  -3.302795  1.112811
# 1610612753 Magic          109.160811           7543.0  -2.249164  1.091608
# 1610612754 Pacers         106.553886           8453.0  -0.070981  1.065539
# 1610612755 76ers          106.832298           8211.0  -1.739931  1.068323
# 1610612756 Suns           109.450005           9291.0   8.255055  1.094500
# 1610612757 Trail Blazers  109.351095           7582.0  -4.719516  1.093511
# 1610612758 Kings          110.649731           8188.0   1.694591  1.106497
# 1610612759 Spurs          102.021592           9448.0   8.349564  1.020216
# 1610612760 Thunder        110.846755           8196.0   2.680999  1.108468
# 1610612761 Raptors        110.573547           7689.0  -0.956403  1.105735
# 1610612762 Jazz           111.878686           7122.0  -5.930782  1.118787
# 1610612763 Grizzlies      106.353399           7193.0   2.289091  1.063534
# 1610612764 Wizards        109.308693           8766.0  -1.076743  1.093087
# 1610612765 Pistons        102.365931           9510.0   5.091089  1.023659
# 1610612766 Hornets        109.595283           7462.0  -7.037329  1.095953
#
# [30 rows x 27 columns]

# %%
conferences = {"Hawks":"East", "Celtics":"East", "Cavaliers":"East", "Bulls":"East", "Heat":"East",
               "Bucks":"East", "Nets":"East", "Knicks":"East", "Magic":"East", "Pacers":"East",
               "76ers":"East", "Raptors":"East", "Wizards":"East", "Pistons":"East", "Hornets":"East",
               
              "Pelicans":"West", "Mavericks":"West", "Nuggets":"West", "Warriors":"West", "Rockets":"West",
              "Clippers":"West", "Lakers":"West", "Timberwolves":"West", "Suns":"West", "Trail Blazers":"West",
              "Kings":"West", "Spurs":"West", "Thunder":"West", "Jazz":"West", "Grizzlies":"West"}

# %%
season_cleaned_efficiency['id'] = season_cleaned_efficiency.index

# %%
def conference_map(team):
    return conferences[team['id'][2]]

# %%
season_cleaned_efficiency['CONFERENCE'] = season_cleaned_efficiency.apply(lambda row: conference_map(row), axis=1)
season_cleaned_efficiency = season_cleaned_efficiency.drop(['id'], axis=1)
season_cleaned_efficiency
# Out:
#                                 GAME_ID     FGM     FGA    FG_PCT   FG3M  \
# SEASON TEAM_ID    TEAM_NAME
# 2003   1610612737 Hawks      1674947672  2857.0  6609.0  0.432289  422.0
#        1610612738 Celtics    1836147889  2994.0  6775.0  0.441919  577.0
#        1610612739 Cavaliers  1685248550  2992.0  6903.0  0.433435  254.0
#        1610612740 Pelicans   1946749139  2977.0  7139.0  0.417005  572.0
#        1610612741 Bulls      1654647953  2781.0  6721.0  0.413778  425.0
# ...                                 ...     ...     ...       ...    ...
# 2020   1610612762 Jazz         36000073   118.0   248.0  0.475806   53.0
#        1610612763 Grizzlies    48000117   166.0   368.0  0.451087   60.0
#        1610612764 Wizards      36000095   111.0   264.0  0.420455   36.0
#        1610612765 Pistons      48000098   132.0   322.0  0.409938   49.0
#        1610612766 Hornets      48000105   157.0   353.0  0.444759   58.0
#
#                                FG3A   FG3_PCT     FTM     FTA    FT_PCT  ...  \
# SEASON TEAM_ID    TEAM_NAME                                              ...
# 2003   1610612737 Hawks      1256.0  0.335987  1555.0  2004.0  0.775948  ...
#        1610612738 Celtics    1676.0  0.344272  1673.0  2229.0  0.750561  ...
#        1610612739 Cavaliers   804.0  0.315920  1564.0  2087.0  0.749401  ...
#        1610612740 Pelicans   1796.0  0.318486  1567.0  2082.0  0.752642  ...
#        1610612741 Bulls      1241.0  0.342466  1329.0  1835.0  0.724251  ...
# ...                             ...       ...     ...     ...       ...  ...
# 2020   1610612762 Jazz        132.0  0.401515    66.0    83.0  0.795181  ...
#        1610612763 Grizzlies   171.0  0.350877    82.0   115.0  0.713043  ...
#        1610612764 Wizards     115.0  0.313043    41.0    60.0  0.683333  ...
#        1610612765 Pistons     150.0  0.326667    63.0    88.0  0.715909  ...
#        1610612766 Hornets     147.0  0.394558    77.0   105.0  0.733333  ...
#
#                                 PTS  POSSESSIONS       PPP         OER  \
# SEASON TEAM_ID    TEAM_NAME
# 2003   1610612737 Hawks      7691.0       7467.0  1.029999  102.999866
#        1610612738 Celtics    8238.0       7917.0  1.040546  104.054566
#        1610612739 Cavaliers  7802.0       7576.0  1.029831  102.983105
#        1610612740 Pelicans   8093.0       7813.0  1.035838  103.583771
#        1610612741 Bulls      7316.0       7432.0  0.984392   98.439182
# ...                             ...          ...       ...         ...
# 2020   1610612762 Jazz        355.0        294.0  1.207483  120.748299
#        1610612763 Grizzlies   474.0        433.0  1.094688  109.468822
#        1610612764 Wizards     299.0        309.0  0.967638   96.763754
#        1610612765 Pistons     376.0        400.0  0.940000   94.000000
#        1610612766 Hornets     449.0        423.0  1.061466  106.146572
#
#                              OPP_PTS         DER  POSSESSIONS_OPP        NER  \
# SEASON TEAM_ID    TEAM_NAME
# 2003   1610612737 Hawks       8075.0  108.084594           7471.0  -5.084728
#        1610612738 Celtics     8439.0  105.672427           7986.0  -1.617861
#        1610612739 Cavaliers   8010.0  105.826397           7569.0  -2.843293
#        1610612740 Pelicans    8122.0  104.154912           7798.0  -0.571141
#        1610612741 Bulls       7829.0  105.285100           7436.0  -6.845918
# ...                              ...         ...              ...        ...
# 2020   1610612762 Jazz         302.0  103.071672            293.0  17.676627
# 1610612747 Lakers         103.340829           9339.0  3.275327  1.033408
# 1610612758 Kings          106.472417           8683.0  4.440008  1.064724
# 1610612742 Mavericks      109.219858           8178.0  4.486470  1.092199
# 1610612750 Timberwolves   101.739937           8621.0  5.787446  1.017399
# 1610612765 Pistons         97.086847           9131.0  6.403935  0.970868
# 1610612754 Pacers          98.973747           8380.0  6.497704  0.989737
# 1610612759 Spurs           96.810764           8027.0  7.761306  0.968108
#
#                           CONFERENCE
# TEAM_ID    TEAM_NAME
# 1610612753 Magic                East
# 1610612741 Bulls                East
# 1610612746 Clippers             West
# 1610612764 Wizards              East
# 1610612737 Hawks                East
# 1610612756 Suns                 West
# 1610612761 Raptors              East
# 1610612739 Cavaliers            East
# 1610612755 76ers                East
# 1610612752 Knicks               East
# 1610612738 Celtics              East
# 1610612757 Trail Blazers        West
# 1610612762 Jazz                 West
# 1610612760 Thunder              West
# 1610612744 Warriors             West
# 1610612740 Pelicans             West
# 1610612749 Bucks                East
# 1610612743 Nuggets              West
# 1610612748 Heat                 East
# 1610612745 Rockets              West
# 1610612763 Grizzlies            West
# 1610612751 Nets                 East
# 1610612747 Lakers               West
# 1610612758 Kings                West
# 1610612742 Mavericks            West
# 1610612750 Timberwolves         West
# 1610612765 Pistons              East
# 1610612754 Pacers               East
# 1610612759 Spurs                West
#
# [29 rows x 28 columns]

# %%
season_cleaned_efficiency.loc[2019].sort_values(by=['NER'])['NER'].plot(kind='barh', figsize=(5, 13), title='2019 Net Efficiency Rating')
plt.axvline(x=0,linewidth=1, color='k')
plt.show()

# %%
cleaned_efficiency.groupby(['SEASON']).mean()['OER'].loc[2003:2019].plot()

# %%
cleaned_efficiency.groupby(['SEASON']).mean().loc[2003:2019]['OER'].plot(title='Average team offensive rating per season', figsize=(13,5))
plt.ylabel('Team offensive rating', fontsize=12)
plt.show()

# %% [markdown]
# # Save dataset

# %%
cleaned_efficiency.to_csv(EFFICIENCY_RATING_DATASET, index=False)
cleaned_efficiency.columns, EFFICIENCY_RATING_DATASET
# Out:
# (Index(['GAME_DATE_EST', 'SEASON', 'GAME_ID', 'TEAM_ID', 'HOME', 'FGM', 'FGA',
#         'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB',
#         'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS', 'POSSESSIONS',
#         'PPP', 'OER', 'OPP_PTS', 'DER', 'POSSESSIONS_OPP', 'NER', 'TEAM_NAME'],
#        dtype='object'),
#  '../../data/processed/110_team_efficiency.csv')

# %%
season_cleaned_efficiency.to_csv(TEAM_SEASONAL_EFFICIENCY_DATASET, index=True)
season_cleaned_efficiency.columns, TEAM_SEASONAL_EFFICIENCY_DATASET
# Out:
# (Index(['GAME_ID', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#         'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF',
#         'PTS', 'POSSESSIONS', 'PPP', 'OER', 'OPP_PTS', 'DER', 'POSSESSIONS_OPP',
#         'NER', 'OPP_PPP', 'CONFERENCE'],
#        dtype='object'),
#  '../../data/processed/111_seasonal_efficiency.csv')

# %% [markdown]
# # Clear dataframes
# This project contains many dataframes. To make sure we don't run out of memory we will delete our dataframes at the end of each notebook.

# %%
# %reset -f
