# %% [markdown]
# # Introduction
# In this notebook I will be collecting the shot data that will be used for the project. I will be picking multiple key players to test some things on and show how the `nba_api` library works. I will then read the shot data that I collected earlier from a locally stored file.

# %% [markdown]
# ## Notebook Objective
# The objective of this notebook is to collect and clean shot data.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
pip install nba_api
# Out:
# Requirement already satisfied: nba_api in c:\users\user\anaconda3\lib\site-packages (1.1.9)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from nba_api) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->nba_api) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->nba_api) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->nba_api) (1.25.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->nba_api) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request, json
from unicodedata import normalize
import seaborn as sns
import os 
import sys

# %%
from nba_api.stats.static import players
from nba_api.stats.static import teams
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import leaguedashplayershotlocations
from nba_api.stats.endpoints import playerdashptshots
from nba_api.stats.endpoints import shotchartdetail

# %% [markdown]
# # Parameters

# %%
# In
SHOT_DATASET = '../../data/raw/shot_dataset.csv'
NBA_GAMES_DATASET = '../../data/raw/players.csv'

# Out
CLEAN_SHOT_DATASET = '../../data/processed/002_shot_dataset.csv'

# %% [markdown]
# ## Configuration

# %%
# %matplotlib inline

# %% [markdown]
# # Gathering Data
# First let's get a basic understanding of the how this library works.

# %%
nba_players = players.get_players()
nba_players[103:107]
# Out:
# [{'id': 1628387,
#   'full_name': 'Ike Anigbogu',
#   'first_name': 'Ike',
#   'last_name': 'Anigbogu',
#   'is_active': False},
#  {'id': 76050,
#   'full_name': 'Michael Ansley',
#   'first_name': 'Michael',
#   'last_name': 'Ansley',
#   'is_active': False},
#  {'id': 1512,
#   'full_name': 'Chris Anstey',
#   'first_name': 'Chris',
#   'last_name': 'Anstey',
#   'is_active': False},
#  {'id': 203507,
#   'full_name': 'Giannis Antetokounmpo',
#   'first_name': 'Giannis',
#   'last_name': 'Antetokounmpo',
#   'is_active': True}]

# %%
test_player = [player for player in nba_players
                   if player['full_name'] == 'Dirk Nowitzki'][0]
test_player
# Out:
# {'id': 1717,
#  'full_name': 'Dirk Nowitzki',
#  'first_name': 'Dirk',
#  'last_name': 'Nowitzki',
#  'is_active': False}

# %% [markdown]
# We will also need to gather team id's and team names

# %%
nba_teams = teams.get_teams()
for team in nba_teams:
    print(str(team['id']) + " " + team['full_name'])
# Out:
# 1610612737 Atlanta Hawks
# 1610612738 Boston Celtics
# 1610612739 Cleveland Cavaliers
# 1610612740 New Orleans Pelicans
# 1610612741 Chicago Bulls
# 1610612742 Dallas Mavericks
# 1610612743 Denver Nuggets
# 1610612744 Golden State Warriors
# 1610612745 Houston Rockets
# 1610612746 Los Angeles Clippers
# 1610612747 Los Angeles Lakers
# 1610612748 Miami Heat
# 1610612749 Milwaukee Bucks
# 1610612750 Minnesota Timberwolves
# 1610612751 Brooklyn Nets
# 1610612752 New York Knicks
# 1610612753 Orlando Magic
# 1610612754 Indiana Pacers
# 1610612755 Philadelphia 76ers
# 1610612756 Phoenix Suns
# 1610612757 Portland Trail Blazers
# 1610612758 Sacramento Kings
# 1610612759 San Antonio Spurs
# 1610612760 Oklahoma City Thunder
# 1610612761 Toronto Raptors
# 1610612762 Utah Jazz
# 1610612763 Memphis Grizzlies
# 1610612764 Washington Wizards
# 1610612765 Detroit Pistons
# 1610612766 Charlotte Hornets

# %% [markdown]
# This function, `player_shots()`, will return a json containing the shot data of the player we specified while they were playing for the team we specified.

# %%
def player_shots(team, player, season=None):
    response = shotchartdetail.ShotChartDetail(
        team_id=team,
        player_id=player,
        season_nullable=season,
        context_measure_simple = 'FGA',
        season_type_all_star='Regular Season'
    )
    return response

# %% [markdown]
# This function, `player_df()`, will turn the json in to a dataframe.

# %%
def player_df(resp):
    content = json.loads(resp.get_json())
    results = content['resultSets'][0]
    headers = results['headers']
    rows = results['rowSet']
    df = pd.DataFrame(rows)
    df.columns = headers
    return df

# %% [markdown]
# We can now use these functions to get the shot data of some key players.

# %%
chosen_players = ['Kobe Bryant', 'Tim Duncan', 'Dirk Nowitzki', 'Stephen Curry', 'Devin Booker', 'Luka Doncic']

# %%
for player in nba_players:
    if player['full_name'] in chosen_players:
        print(player['full_name'] + ": " + str(player['id']))
# Out:
# Devin Booker: 1626164
# Kobe Bryant: 977
# Stephen Curry: 201939
# Luka Doncic: 1629029
# Tim Duncan: 1495
# Dirk Nowitzki: 1717

# %%
# Played for LA Lakers 1996-2016
K_Bryant = player_shots(1610612747, 977)

# Played for San Antonio Spurs 1997-2016 
T_Duncan = player_shots(1610612759, 1495)

# Played for Dallas Mavericks 1998-2019
D_Nowitzki = player_shots(1610612742, 1717)

# Plays for Golden State Warriors 2009-present
S_Curry = player_shots(1610612744, 201939)

# Plays for the Phoenix Suns 2015-present
D_Booker = player_shots(1610612756, 1626164)

# Plays for Dallas Mavericks 2018-present
L_Doncic = player_shots(1610612742, 1629029)

# %%
KBryant_df = player_df(K_Bryant)
KBryant_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  PLAYER_NAME  \
# 0  Shot Chart Detail  0020000012             10        977  Kobe Bryant
# 1  Shot Chart Detail  0020000012             12        977  Kobe Bryant
# 2  Shot Chart Detail  0020000012             35        977  Kobe Bryant
# 3  Shot Chart Detail  0020000012             43        977  Kobe Bryant
# 4  Shot Chart Detail  0020000012            155        977  Kobe Bryant
#
#       TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612747  Los Angeles Lakers       1                 10
# 1  1610612747  Los Angeles Lakers       1                 10
# 2  1610612747  Los Angeles Lakers       1                  7
# 3  1610612747  Los Angeles Lakers       1                  6
# 4  1610612747  Los Angeles Lakers       2                  6
#
#    SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                 27  ...          Right Side(R)        16-24 ft.
# 1                 22  ...           Left Side(L)         8-16 ft.
# 2                 45  ...   Left Side Center(LC)        16-24 ft.
# 3                 52  ...  Right Side Center(RC)        16-24 ft.
# 4                 19  ...              Center(C)  Less Than 8 ft.
#
#   SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0            18   167    72                   1               0   20001031
# 1            15  -157     0                   1               0   20001031
# 2            16  -101   135                   1               1   20001031
# 3            22   138   175                   1               0   20001031
# 4             0     0     0                   1               1   20001031
#
#    HTM  VTM
# 0  POR  LAL
# 1  POR  LAL
# 2  POR  LAL
# 3  POR  LAL
# 4  POR  LAL
#
# [5 rows x 24 columns]

# %%
KBryant_df.shape
# Out:
# (26198, 24)

# %%
KBryant_df.columns
# Out:
# Index(['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME',
#        'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
#        'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE',
#        'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE',
#        'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE',
#        'HTM', 'VTM'],
#       dtype='object')

# %%
TDuncan_df = player_df(T_Duncan)
DNowitzki_df = player_df(D_Nowitzki)
SCurry_df = player_df(S_Curry)
DBooker_df = player_df(D_Booker)
LDoncic_df = player_df(L_Doncic)

# %%
key_players_shots_df = pd.concat([KBryant_df, TDuncan_df, DNowitzki_df, SCurry_df, DBooker_df, LDoncic_df])
key_players_shots_df.head(5)
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  PLAYER_NAME  \
# 0  Shot Chart Detail  0020000012             10        977  Kobe Bryant
# 1  Shot Chart Detail  0020000012             12        977  Kobe Bryant
# 2  Shot Chart Detail  0020000012             35        977  Kobe Bryant
# 3  Shot Chart Detail  0020000012             43        977  Kobe Bryant
# 4  Shot Chart Detail  0020000012            155        977  Kobe Bryant
#
#       TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612747  Los Angeles Lakers       1                 10
# 1  1610612747  Los Angeles Lakers       1                 10
# 2  1610612747  Los Angeles Lakers       1                  7
# 3  1610612747  Los Angeles Lakers       1                  6
# 4  1610612747  Los Angeles Lakers       2                  6
#
#    SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                 27  ...          Right Side(R)        16-24 ft.
# 1                 22  ...           Left Side(L)         8-16 ft.
# 2                 45  ...   Left Side Center(LC)        16-24 ft.
# 3                 52  ...  Right Side Center(RC)        16-24 ft.
# 4                 19  ...              Center(C)  Less Than 8 ft.
#
#   SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0            18   167    72                   1               0   20001031
# 1            15  -157     0                   1               0   20001031
# 2            16  -101   135                   1               1   20001031
# 3            22   138   175                   1               0   20001031
# 4             0     0     0                   1               1   20001031
#
#    HTM  VTM
# 0  POR  LAL
# 1  POR  LAL
# 2  POR  LAL
# 3  POR  LAL
# 4  POR  LAL
#
# [5 rows x 24 columns]

# %%
key_players_shots_df.shape
# Out:
# (94194, 24)

# %%
key_players_shots_df.isnull().sum()
# Out:
# GRID_TYPE              0
# GAME_ID                0
# GAME_EVENT_ID          0
# PLAYER_ID              0
# PLAYER_NAME            0
# TEAM_ID                0
# TEAM_NAME              0
# PERIOD                 0
# MINUTES_REMAINING      0
# SECONDS_REMAINING      0
# EVENT_TYPE             0
# ACTION_TYPE            0
# SHOT_TYPE              0
# SHOT_ZONE_BASIC        0
# SHOT_ZONE_AREA         0
# SHOT_ZONE_RANGE        0
# SHOT_DISTANCE          0
# LOC_X                  0
# LOC_Y                  0
# SHOT_ATTEMPTED_FLAG    0
# SHOT_MADE_FLAG         0
# GAME_DATE              0
# HTM                    0
# VTM                    0
# dtype: int64

# %%
key_players_shots_df[key_players_shots_df['TEAM_ID'] == 1610612742]
# Out:
#               GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0     Shot Chart Detail  0020000007             34       1717  Dirk Nowitzki
# 1     Shot Chart Detail  0020000007             49       1717  Dirk Nowitzki
# 2     Shot Chart Detail  0020000007            174       1717  Dirk Nowitzki
# 3     Shot Chart Detail  0020000007            186       1717  Dirk Nowitzki
# 4     Shot Chart Detail  0020000007            274       1717  Dirk Nowitzki
# ...                 ...         ...            ...        ...            ...
# 3665  Shot Chart Detail  0022000986            377    1629029    Luka Doncic
# 3666  Shot Chart Detail  0022000986            389    1629029    Luka Doncic
# 3667  Shot Chart Detail  0022000986            413    1629029    Luka Doncic
# 3668  Shot Chart Detail  0022000986            448    1629029    Luka Doncic
# 3669  Shot Chart Detail  0022000986            461    1629029    Luka Doncic
#
#          TEAM_ID         TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0     1610612742  Dallas Mavericks       1                  8
# 1     1610612742  Dallas Mavericks       1                  6
# 2     1610612742  Dallas Mavericks       2                  7
# 3     1610612742  Dallas Mavericks       2                  5
# 4     1610612742  Dallas Mavericks       3                 10
# ...          ...               ...     ...                ...
# 3665  1610612742  Dallas Mavericks       3                  8
# 3666  1610612742  Dallas Mavericks       3                  6
# 3667  1610612742  Dallas Mavericks       3                  4
# 3668  1610612742  Dallas Mavericks       3                  2
# 3669  1610612742  Dallas Mavericks       3                  1
#
#       SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                     8  ...              Center(C)  Less Than 8 ft.
# 1                    31  ...   Left Side Center(LC)          24+ ft.
# 2                    17  ...           Left Side(L)          24+ ft.
# 3                    37  ...          Right Side(R)        16-24 ft.
# 4                    32  ...   Left Side Center(LC)          24+ ft.
# ...                 ...  ...                    ...              ...
# 3665                  8  ...  Right Side Center(RC)          24+ ft.
# 3666                 55  ...   Left Side Center(LC)          24+ ft.
# 3667                 28  ...   Left Side Center(LC)          24+ ft.
# 3668                 14  ...              Center(C)          24+ ft.
# 3669                 14  ...           Left Side(L)         8-16 ft.
#
#      SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0                0     0     0                   1               0   20001031
# 1               24  -103   226                   1               0   20001031
# 2               23  -231     2                   1               1   20001031
# 3               18   159   104                   1               1   20001031
# 4               25  -126   219                   1               0   20001031
# ...            ...   ...   ...                 ...             ...        ...
# 3665            28    89   269                   1               0   20210504
# 3666            25  -140   213                   1               0   20210504
# 3667            26  -138   231                   1               1   20210504
# 3668            26    11   264                   1               0   20210504
# 3669            14  -133    61                   1               0   20210504
#
#       HTM  VTM
# 0     DAL  MIL
# 1     DAL  MIL
# 2     DAL  MIL
# 3     DAL  MIL
# 4     DAL  MIL
# ...   ...  ...
# 3665  MIA  DAL
# 3666  MIA  DAL
# 3667  MIA  DAL
# 3668  MIA  DAL
# 3669  MIA  DAL
#
# [27404 rows x 24 columns]

# %% [markdown]
# We can use operations on this dataframe to find specific data. Let's look at every 3 point buzzer beater scored by one of our key players.

# %%
key_players_shots_df[(key_players_shots_df['PERIOD'] == 4) & (key_players_shots_df['MINUTES_REMAINING'] < 1)  &
                     (key_players_shots_df['SECONDS_REMAINING'] < 1) & (key_players_shots_df['SHOT_MADE_FLAG'] == 1) &
                     (key_players_shots_df['SHOT_TYPE'] == '3PT Field Goal')]
# Out:
#                GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 15265  Shot Chart Detail  0020900281            599        977    Kobe Bryant
# 15611  Shot Chart Detail  0020900476            520        977    Kobe Bryant
# 3437   Shot Chart Detail  0020200422            450       1495     Tim Duncan
# 3968   Shot Chart Detail  0020200881            485       1495     Tim Duncan
# 241    Shot Chart Detail  0020000246            502       1717  Dirk Nowitzki
# 10909  Shot Chart Detail  0020701174            427       1717  Dirk Nowitzki
# 22441  Shot Chart Detail  0029800393            420       1717  Dirk Nowitzki
# 23012  Shot Chart Detail  0029900418            472       1717  Dirk Nowitzki
# 448    Shot Chart Detail  0021800495            651    1629029    Luka Doncic
# 3100   Shot Chart Detail  0022000485            617    1629029    Luka Doncic
# 3487   Shot Chart Detail  0022000837            611    1629029    Luka Doncic
#
#           TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 15265  1610612747  Los Angeles Lakers       4                  0
# 15611  1610612747  Los Angeles Lakers       4                  0
# 3437   1610612759   San Antonio Spurs       4                  0
# 3968   1610612759   San Antonio Spurs       4                  0
# 241    1610612742    Dallas Mavericks       4                  0
# 10909  1610612742    Dallas Mavericks       4                  0
# 22441  1610612742    Dallas Mavericks       4                  0
# 23012  1610612742    Dallas Mavericks       4                  0
# 448    1610612742    Dallas Mavericks       4                  0
# 3100   1610612742    Dallas Mavericks       4                  0
# 3487   1610612742    Dallas Mavericks       4                  0
#
#        SECONDS_REMAINING  ...         SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 15265                  0  ...              Center(C)         24+ ft.
# 15611                  0  ...   Left Side Center(LC)         24+ ft.
# 3437                   0  ...  Right Side Center(RC)         24+ ft.
# 3968                   0  ...              Center(C)         24+ ft.
# 241                    0  ...  Right Side Center(RC)         24+ ft.
# 10909                  0  ...   Left Side Center(LC)         24+ ft.
# 22441                  0  ...   Left Side Center(LC)         24+ ft.
# 23012                  0  ...  Right Side Center(RC)         24+ ft.
# 448                    0  ...          Right Side(R)         24+ ft.
# 3100                   0  ...   Left Side Center(LC)         24+ ft.
# 3487                   0  ...   Left Side Center(LC)         24+ ft.
#
#       SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  \
# 15265            27     6   274                   1               1
# 15611            25  -235    91                   1               1
# 3437             24   118   214                   1               1
# 3968             24   -36   247                   1               1
# 241              28   108   268                   1               1
# 10909            24  -199   143                   1               1
# 22441            24  -136   201                   1               1
# 23012            24   224   106                   1               1
# 448              22   220    12                   1               1
# 3100             27  -155   227                   1               1
# 3487             24  -125   210                   1               1
#
#        GAME_DATE  HTM  VTM
# 15265   20091204  LAL  MIA
# 15611   20100101  LAL  SAC
# 3437    20021228  CHI  SAS
# 3968    20030306  SAS  NJN
# 241     20001203  LAL  DAL
# 10909   20080410  DAL  UTA
# 22441   19990326  DAL  DEN
# 23012   19991230  DAL  TOR
# 448     20181223  POR  DAL
# 3100    20210223  DAL  BOS
# 3487    20210414  MEM  DAL
#
# [11 rows x 24 columns]

# %%
key_players_shots_df.groupby(['PLAYER_ID', 'PLAYER_NAME', 'GAME_ID', 'GAME_EVENT_ID']).sum().loc[977]
# Out:
#                                          TEAM_ID  PERIOD  MINUTES_REMAINING  \
# PLAYER_NAME GAME_ID    GAME_EVENT_ID
# Kobe Bryant 0020000012 10             1610612747       1                 10
#                        12             1610612747       1                 10
#                        35             1610612747       1                  7
#                        43             1610612747       1                  6
#                        155            1610612747       2                  6
# ...                                          ...     ...                ...
#             0029901185 450            1610612747       4                  0
#                        457            1610612747       5                  4
#                        496            1610612747       5                  0
#                        505            1610612747       5                  0
#                        512            1610612747       5                  0
#
#                                       SECONDS_REMAINING  SHOT_DISTANCE  LOC_X  \
# PLAYER_NAME GAME_ID    GAME_EVENT_ID
# Kobe Bryant 0020000012 10                            27             18    167
#                        12                            22             15   -157
#                        35                            45             16   -101
#                        43                            52             22    138
#                        155                           19              0      0
# ...                                                 ...            ...    ...
#             0029901185 450                            0             19   -141
#                        457                           26              1    -12
#                        496                           41             24    164
#                        505                           21             24   -237
#                        512                            8             28    156
#
#                                       LOC_Y  SHOT_ATTEMPTED_FLAG  \
# PLAYER_NAME GAME_ID    GAME_EVENT_ID
# Kobe Bryant 0020000012 10                72                    1
#                        12                 0                    1
#                        35               135                    1
#                        43               175                    1
#                        155                0                    1
# ...                                     ...                  ...
#             0029901185 450              128                    1
#                        457                5                    1
#                        496              179                    1
#                        505               70                    1
#                        512              233                    1
#
#                                       SHOT_MADE_FLAG
# PLAYER_NAME GAME_ID    GAME_EVENT_ID
# Kobe Bryant 0020000012 10                          0
#                        12                          0
#                        35                          1
#                        43                          0
#                        155                         1
# ...                                              ...
#             0029901185 450                         0
#                        457                         0
#                        496                         1
#                        505                         1
#                        512                         0
#
# [26198 rows x 9 columns]

# %% [markdown]
# # Finish gathering data

# %%
games = pd.read_csv(NBA_GAMES_DATASET)
games.shape, games.dtypes
# Out:
# ((7228, 4),
#  PLAYER_NAME    object
#  TEAM_ID         int64
#  PLAYER_ID       int64
#  SEASON          int64
#  dtype: object)

# %%
games.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
players = list(games.groupby(['TEAM_ID', 'PLAYER_ID']).groups)

# %%
len(players)
# Out:
# 4281

# %% [markdown]
# We can use one of our previous dataframes to get the structure of the new dataframe. We will then append each new players shots to this dataframe.

# %%
all_shot_df = KBryant_df[KBryant_df['TEAM_ID'] == 0]
all_shot_df
# Out:
# Empty DataFrame
# Columns: [GRID_TYPE, GAME_ID, GAME_EVENT_ID, PLAYER_ID, PLAYER_NAME, TEAM_ID, TEAM_NAME, PERIOD, MINUTES_REMAINING, SECONDS_REMAINING, EVENT_TYPE, ACTION_TYPE, SHOT_TYPE, SHOT_ZONE_BASIC, SHOT_ZONE_AREA, SHOT_ZONE_RANGE, SHOT_DISTANCE, LOC_X, LOC_Y, SHOT_ATTEMPTED_FLAG, SHOT_MADE_FLAG, GAME_DATE, HTM, VTM]
# Index: []
#
# [0 rows x 24 columns]

# %%
# This is how I gathered the data. It is now stored locally in SHOT_DATASET
"""
for player in players:
    # use a try except block to filter players that have taken no shots in their career
    # (players that haven't taken shots throw an error when appended to the dataframe)
    try:
        resp = player_shots(player[0], player[1])
        test_df = test_df.append(player_df(resp), ignore_index=True)
    except:
        pass
"""
# Out:
# "\nfor player in players:\n    # use a try except block to filter players that have taken no shots in their career\n    # (players that haven't taken shots throw an error when appended to the dataframe)\n    try:\n        resp = player_shots(player[0], player[1])\n        test_df = test_df.append(player_df(resp), ignore_index=True)\n    except:\n        pass\n"

# %%
all_shot_data = pd.read_csv(SHOT_DATASET)
all_shot_data.shape, all_shot_data.dtypes
# Out:
# ((2892449, 24),
#  GRID_TYPE              object
#  GAME_ID                 int64
#  GAME_EVENT_ID           int64
#  PLAYER_ID               int64
#  PLAYER_NAME            object
#  TEAM_ID                 int64
#  TEAM_NAME              object
#  PERIOD                  int64
#  MINUTES_REMAINING       int64
#  SECONDS_REMAINING       int64
#  EVENT_TYPE             object
#  ACTION_TYPE            object
#  SHOT_TYPE              object
#  SHOT_ZONE_BASIC        object
#  SHOT_ZONE_AREA         object
#  SHOT_ZONE_RANGE        object
#  SHOT_DISTANCE           int64
#  LOC_X                   int64
#  LOC_Y                   int64
#  SHOT_ATTEMPTED_FLAG     int64
#  SHOT_MADE_FLAG          int64
#  GAME_DATE               int64
#  HTM                    object
#  VTM                    object
#  dtype: object)

# %%
all_shot_data.groupby(['PLAYER_ID']).sum().shape
# Out:
# (1347, 12)

# %%
all_shot_data.isnull().sum()
# Out:
# GRID_TYPE               0
# GAME_ID                 0
# GAME_EVENT_ID           0
# PLAYER_ID               0
# PLAYER_NAME            58
# TEAM_ID                 0
# TEAM_NAME               0
# PERIOD                  0
# MINUTES_REMAINING       0
# SECONDS_REMAINING       0
# EVENT_TYPE              0
# ACTION_TYPE             0
# SHOT_TYPE               0
# SHOT_ZONE_BASIC         0
# SHOT_ZONE_AREA          0
# SHOT_ZONE_RANGE         0
# SHOT_DISTANCE           0
# LOC_X                   0
# LOC_Y                   0
# SHOT_ATTEMPTED_FLAG     0
# SHOT_MADE_FLAG          0
# GAME_DATE               0
# HTM                     0
# VTM                     0
# dtype: int64

# %%
all_shot_data = all_shot_data.dropna()
all_shot_data.isnull().sum()
# Out:
# GRID_TYPE              0
# GAME_ID                0
# GAME_EVENT_ID          0
# PLAYER_ID              0
# PLAYER_NAME            0
# TEAM_ID                0
# TEAM_NAME              0
# PERIOD                 0
# MINUTES_REMAINING      0
# SECONDS_REMAINING      0
# EVENT_TYPE             0
# ACTION_TYPE            0
# SHOT_TYPE              0
# SHOT_ZONE_BASIC        0
# SHOT_ZONE_AREA         0
# SHOT_ZONE_RANGE        0
# SHOT_DISTANCE          0
# LOC_X                  0
# LOC_Y                  0
# SHOT_ATTEMPTED_FLAG    0
# SHOT_MADE_FLAG         0
# GAME_DATE              0
# HTM                    0
# VTM                    0
# dtype: int64

# %% [markdown]
# Let's write a funciton to make a season column for each shot. We can do this using the `GAME_ID` columns.

# %%
def season(game):
    seas = str(game['GAME_ID'])[1:3]
    if int(seas) > 21:
        return int('19' + seas)
    else:
        return int('20' + seas)

# %%
all_shot_data['SEASON'] = all_shot_data.apply(lambda row: season(row), axis=1)

# %%
all_shot_data[(all_shot_data['TEAM_NAME'] == 'Dallas Mavericks') & (all_shot_data['SEASON'] == 2011)]
# Out:
#                  GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 170150   Shot Chart Detail  21100002            311        467
# 170151   Shot Chart Detail  21100002            331        467
# 170152   Shot Chart Detail  21100002            346        467
# 170153   Shot Chart Detail  21100002            443        467
# 170154   Shot Chart Detail  21100002            465        467
# ...                    ...       ...            ...        ...
# 1277161  Shot Chart Detail  21100983            137     202346
# 1277162  Shot Chart Detail  21100983            367     202346
# 1277163  Shot Chart Detail  21100983            384     202346
# 1277164  Shot Chart Detail  21100983            407     202346
# 1277165  Shot Chart Detail  21100983            428     202346
#
#              PLAYER_NAME     TEAM_ID         TEAM_NAME  PERIOD  \
# 170150        Jason Kidd  1610612742  Dallas Mavericks       2
# 170151        Jason Kidd  1610612742  Dallas Mavericks       2
# 170152        Jason Kidd  1610612742  Dallas Mavericks       3
# 170153        Jason Kidd  1610612742  Dallas Mavericks       3
# 170154        Jason Kidd  1610612742  Dallas Mavericks       3
# ...                  ...         ...               ...     ...
# 1277161  Dominique Jones  1610612742  Dallas Mavericks       2
# 1277162  Dominique Jones  1610612742  Dallas Mavericks       4
# 1277163  Dominique Jones  1610612742  Dallas Mavericks       4
# 1277164  Dominique Jones  1610612742  Dallas Mavericks       4
# 1277165  Dominique Jones  1610612742  Dallas Mavericks       4
#
#          MINUTES_REMAINING  SECONDS_REMAINING  ...  SHOT_ZONE_RANGE  \
# 170150                   1                 24  ...          24+ ft.
# 170151                   0                 10  ...          24+ ft.
# 170152                  11                 45  ...          24+ ft.
# 170153                   2                 28  ...          24+ ft.
# 170154                   0                 26  ...          24+ ft.
# ...                    ...                ...  ...              ...
# 1277161                  9                 17  ...  Less Than 8 ft.
# 1277162                  9                 18  ...  Less Than 8 ft.
# 1277163                  7                 41  ...  Less Than 8 ft.
# 1277164                  6                 23  ...        16-24 ft.
# 1277165                  4                 46  ...          24+ ft.
#
#         SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG SHOT_MADE_FLAG  \
# 170150             24   176   170                   1              1
# 170151             24   132   201                   1              1
# 170152             24   196   143                   1              0
# 170153             24   -35   244                   1              0
# 170154             24   225   102                   1              0
# ...               ...   ...   ...                 ...            ...
# 1277161             5   -56    20                   1              0
# 1277162             0     2     4                   1              0
# 1277163             1   -10     3                   1              0
# 1277164            20   -97   179                   1              0
# 1277165            24   -73   230                   1              0
#
#          GAME_DATE  HTM  VTM  SEASON
# 170150    20111225  DAL  MIA    2011
# 170151    20111225  DAL  MIA    2011
# 170152    20111225  DAL  MIA    2011
# 170153    20111225  DAL  MIA    2011
# 170154    20111225  DAL  MIA    2011
# ...            ...  ...  ...     ...
# 1277161   20120426  ATL  DAL    2011
# 1277162   20120426  ATL  DAL    2011
# 1277163   20120426  ATL  DAL    2011
# 1277164   20120426  ATL  DAL    2011
# 1277165   20120426  ATL  DAL    2011
#
# [5412 rows x 25 columns]

# %% [markdown]
# Some teams have changed names over the years. To correct this we will make a dictionary of each teams current name and apply it across the dataset.

# %%
all_shot_data.groupby(['TEAM_ID', 'TEAM_NAME']).mean()
# Out:
#                                                    GAME_ID  GAME_EVENT_ID  \
# TEAM_ID    TEAM_NAME
# 1610612737 Atlanta Haw
# 1610612755 Philadelphia 76ers            0.447963  2.011808e+07  2011.114560
# 1610612756 Phoenix Suns                  0.468243  2.013253e+07  2012.567640
# 1610612757 Portland Trail Blazers        0.455039  2.013845e+07  2013.155686
# 1610612758 Sacramento Kings              0.455954  2.013971e+07  2013.271352
# 1610612759 San Antonio Spurs             0.475811  2.011931e+07  2011.241584
# 1610612760 Oklahoma City Thunder         0.462507  2.014184e+07  2013.495378
# 1610612761 Toronto Raptors               0.462280  2.013997e+07  2013.306343
# 1610612762 Utah Jazz                     0.466588  2.012866e+07  2012.181828
# 1610612763 Memphis Grizzlies             0.453204  2.013299e+07  2012.607146
# 1610612764 Washington Wizards            0.454786  2.012840e+07  2012.142404
# 1610612765 Detroit Pistons               0.447176  2.012222e+07  2011.542790
# 1610612766 Charlotte Hornets             0.439830  2.013816e+07  2013.123748

# %%
clean_all_shot_data.columns
# Out:
# Index(['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME',
#        'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
#        'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE',
#        'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE',
#        'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE',
#        'HTM', 'VTM', 'SEASON'],
#       dtype='object')

# %%
clean_all_shot_data['GRID_TYPE'].unique()
# Out:
# array(['Shot Chart Detail'], dtype=object)

# %%
clean_all_shot_data['EVENT_TYPE'].unique()
# Out:
# array(['Missed Shot', 'Made Shot'], dtype=object)

# %% [markdown]
# We can drop `GRID_TYPE` because this column doesn't provide any useful information. We can drop `EVENT_TYPE` because this data is already stored in `SHOT_MADE_FLAG`.

# %%
clean_all_shot_data= clean_all_shot_data.drop(columns=['GRID_TYPE', 'EVENT_TYPE'])

# %%
clean_all_shot_data.columns
# Out:
# Index(['GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID',
#        'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING',
#        'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA',
#        'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y',
#        'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM',
#        'SEASON'],
#       dtype='object')

# %% [markdown]
# We can also drop `PERIOD`, `MINUTES_REMAINING`, `SECONDS_REMAINING`, `ACTION_TYPE`, `HTM` and `VTM` because I won't be using these columns at any point in this project.

# %%
clean_all_shot_data= clean_all_shot_data.drop(columns=['PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'ACTION_TYPE', 'HTM', 'VTM'])

# %% [markdown]
# ## Filter unwanted seasons
# This is a very large dataset so reducing it as much as possible is important. We will not be looking at any shot data before 2009 because we don't have the full data for those seasons. Let's filter our dataframe to remove all seasons before 2009.

# %%
final_shots = clean_all_shot_data[clean_all_shot_data['SEASON']>2008].copy()
final_shots.shape, final_shots.dtypes
# Out:
# ((2293539, 17),
#  GAME_ID                 int64
#  GAME_EVENT_ID           int64
#  PLAYER_ID               int64
#  PLAYER_NAME            object
#  TEAM_ID                 int64
#  TEAM_NAME              object
#  SHOT_TYPE              object
#  SHOT_ZONE_BASIC        object
#  SHOT_ZONE_AREA         object
#  SHOT_ZONE_RANGE        object
#  SHOT_DISTANCE           int64
#  LOC_X                   int64
#  LOC_Y                   int64
#  SHOT_ATTEMPTED_FLAG     int64
#  SHOT_MADE_FLAG          int64
#  GAME_DATE               int64
#  SEASON                  int64
#  dtype: object)

# %% [markdown]
# # Save Dataset
# Now that the dataset has been cleaned and reduced we can save the new dataset

# %%
final_shots.to_csv(CLEAN_SHOT_DATASET, index=False)

# %% [markdown]
# # Clear dataframes
# This project contains many dataframes. To make sure we don't run out of memory we will delete our dataframes at the end of each notebook.

# %%
# %reset -f
